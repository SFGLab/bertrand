# %%
import sys

# %%
sys.path.append('../..')

# %%
import os

# %%
from bertrand.model import BERTrand
from bertrand.model.inference import PeptideTCRDataset, single_obs_to_tensor

model = BERTrand.from_pretrained("/mnt/storage2/olek/bertrand-gdrive/training/dataset_42/cv_seed=42/best_checkpoint/") # see Downloads section
model.eval() # don't forget this
# Out:
# BERTrand(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(25, 512, padding_idx=0)
#       (position_embeddings): Embedding(64, 512)
#       (token_type_embeddings): Embedding(2, 512)
#       (LayerNorm): LayerNorm((512,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=512, out_features=512, bias=True)
#               (key): Linear(in_features=512, out_features=512, bias=True)
#               (value): Linear(in_features=512, out_features=512, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=512, out_features=512, bias=True)
# ...

# %%
model.bert
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(25, 512, padding_idx=0)
#     (position_embeddings): Embedding(64, 512)
#     (token_type_embeddings): Embedding(2, 512)
#     (LayerNorm): LayerNorm((512,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=512, out_features=512, bias=True)
#             (key): Linear(in_features=512, out_features=512, bias=True)
#             (value): Linear(in_features=512, out_features=512, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=512, out_features=512, bias=True)
#             (LayerNorm): LayerNorm((512,), eps=1e-12, elementwise_affine=True)
# ...

# %%
bert_att = model.bert.encoder.layer[0].attention

# %%
bert_att.self.query.bias.shape
# Out:
# torch.Size([512])

# %%
bert_att
# Out:
# BertAttention(
#   (self): BertSelfAttention(
#     (query): Linear(in_features=512, out_features=512, bias=True)
#     (key): Linear(in_features=512, out_features=512, bias=True)
#     (value): Linear(in_features=512, out_features=512, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (output): BertSelfOutput(
#     (dense): Linear(in_features=512, out_features=512, bias=True)
#     (LayerNorm): LayerNorm((512,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
from transformers import BertConfig
from bertrand.model.tokenization import tokenizer

# %%
BERT_CONFIG = BertConfig(
    vocab_size=tokenizer.vocab_size,
    max_position_embeddings=64,
    type_vocab_size=2,
    num_attention_heads=8,
    num_hidden_layers=8,
    hidden_size=512,
    intermediate_size=2048,
)
