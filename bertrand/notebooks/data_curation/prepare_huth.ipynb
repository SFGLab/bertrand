# %%
import pandas as pd
import os

# %% [markdown]
# <h2>CRV

# %%
huth_CRV = pd.read_excel("../../../data/original/huth_original.xlsx", sheet_name = 3)

# %%
huth_CRV
# Out:
#     Supplementary Table 2. Sample metadata and specific TCRβ sequences.  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                               V.gene
# 3                                             TRBV25-1
# 4                                             TRBV25-1
# ..                                                 ...
# 433                                            TRBV7-9
# 434                                            TRBV7-9
# 435                                            TRBV7-9
# 436                                            TRBV7-9
# 437                                            TRBV7-9
#
#            Unnamed: 1 Unnamed: 2   Unnamed: 3       Unnamed: 4  Unnamed: 5  \
# 0                 NaN        NaN          NaN              NaN         NaN
# 1                 NaN        NaN          NaN              NaN         NaN
# ...

# %%
huth_CRV.columns = huth_CRV.iloc[2]

# %%
huth_CRV = huth_CRV.iloc[3:, :-3].reset_index(drop=True)

# %%
huth_CRV.columns = ["TRBV", "CDR3b", "TRBJ", "peptide_seq", "patient"]

# %%
huth_CRV["peptide_seq"] = "CRVLCCYVL"
huth_CRV["HLA_type"] = "C07:02"
huth_CRV["protein"] = "IE-1"

# %% [markdown]
# <h2>FCR

# %%
huth_FCR = pd.read_excel("../../../data/original/huth_original.xlsx", sheet_name = 4)

# %%
huth_FCR
# Out:
#     Supplementary Table 2. Sample metadata and specific TCRβ sequences.  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                               V.gene
# 3                                               TRBV15
# 4                                               TRBV15
# ..                                                 ...
# 264                                            TRBV7-8
# 265                                            TRBV7-8
# 266                                            TRBV7-9
# 267                                            TRBV7-9
# 268                                              TRBV9
#
#               Unnamed: 1 Unnamed: 2   Unnamed: 3   Unnamed: 4  Unnamed: 5  \
# 0                    NaN        NaN          NaN          NaN         NaN
# 1                    NaN        NaN          NaN          NaN         NaN
# ...

# %%
huth_FCR.columns = huth_FCR.iloc[2]

# %%
huth_FCR = huth_FCR.iloc[3:, :-3].reset_index(drop=True)

# %%
huth_FCR.columns = ["TRBV", "CDR3b", "TRBJ", "peptide_seq", "patient"]

# %%
huth_FCR["peptide_seq"] = "FRCPRRFCF"
huth_FCR["HLA_type"] = "C07:02"
huth_FCR["protein"] = "UL29/28"

# %% [markdown]
# <h2>RPH

# %%
huth_RPH = pd.read_excel("../../../data/original/huth_original.xlsx", sheet_name = 5)

# %%
huth_RPH
# Out:
#     Supplementary Table 2. Sample metadata and specific TCRβ sequences.  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                               V.gene
# 3                                              TRBV4-3
# 4                                              TRBV4-3
# ..                                                 ...
# 189                                            TRBV7-9
# 190                                            TRBV7-9
# 191                                            TRBV7-9
# 192                                              TRBV9
# 193                                              TRBV9
#
#            Unnamed: 1 Unnamed: 2   Unnamed: 3           Unnamed: 4  \
# 0                 NaN        NaN          NaN                  NaN
# 1                 NaN        NaN          NaN                  NaN
# 2       CDR3.sequence     J.gene  Specificity                Donor
# ...

# %%
huth_RPH.columns = huth_RPH.iloc[2]

# %%
huth_RPH = huth_RPH.iloc[3:, :-3].reset_index(drop=True)

# %%
huth_RPH.columns = ["TRBV", "CDR3b", "TRBJ", "peptide_seq", "patient"]

# %%
huth_RPH["peptide_seq"] = "RPHERNGFTVL"
huth_RPH["HLA_type"] = "B07:02"
huth_RPH["protein"] = "pp65"

# %% [markdown]
# <h2>TPR

# %%
huth_TPR = pd.read_excel("../../../data/original/huth_original.xlsx", sheet_name = 6)

# %%
huth_TPR
# Out:
#     Supplementary Table 2. Sample metadata and specific TCRβ sequences.  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                               V.gene
# 3                                              TRBV7-8
# 4                                              TRBV7-9
# ..                                                 ...
# 158                                            TRBV7-9
# 159                                            TRBV7-9
# 160                                            TRBV7-9
# 161                                            TRBV7-9
# 162                                            TRBV7-9
#
#             Unnamed: 1 Unnamed: 2   Unnamed: 3   Unnamed: 4  Unnamed: 5  \
# 0                  NaN        NaN          NaN          NaN         NaN
# 1                  NaN        NaN          NaN          NaN         NaN
# ...

# %%
huth_TPR.columns = huth_TPR.iloc[2]

# %%
huth_TPR = huth_TPR.iloc[3:, :-3].reset_index(drop=True)

# %%
huth_TPR.columns = ["TRBV", "CDR3b", "TRBJ", "peptide_seq", "patient"]

# %%
huth_TPR["peptide_seq"] = "TPRVTGGGAM"
huth_TPR["HLA_type"] = "B07:02"
huth_TPR["protein"] = "pp65"

# %% [markdown]
# <h3>Merge datasets

# %%
huth_merged = pd.concat([huth_CRV, huth_FCR, huth_RPH, huth_TPR], axis=0)

# %%
huth_merged["peptide_source"] = "CMV"
huth_merged["tcr_source_organism"] = "human"
huth_merged["dataset"] ="huth"
huth_merged["tissue"] = "PBMC"
huth_merged["experiment_type"] = "peptide simulation, TCRb sequencing"

# %%
huth_merged["TRBJ"] = huth_merged["TRBJ"].str.replace("TRBJ", "")
huth_merged["TRBV"] = huth_merged["TRBV"].str.replace("TRBV", "")

# %%
huth_merged.columns
# Out:
# Index(['TRBV', 'CDR3b', 'TRBJ', 'peptide_seq', 'patient', 'HLA_type',
#        'protein', 'peptide_source', 'tcr_source_organism', 'dataset', 'tissue',
#        'experiment_type'],
#       dtype='object')

# %%
huth_merged = huth_merged[["peptide_seq", "HLA_type", "CDR3b", "TRBV", "TRBJ", "peptide_source", "protein","tcr_source_organism", "patient", "tissue", "experiment_type", "dataset"]]

# %%
huth_merged
# Out:
#     peptide_seq HLA_type              CDR3b  TRBV TRBJ peptide_source protein  \
# 0     CRVLCCYVL   C07:02        CASSPGDEQFF  25-1  2-1            CMV    IE-1
# 1     CRVLCCYVL   C07:02        CASTPGDEQFF  25-1  2-1            CMV    IE-1
# 2     CRVLCCYVL   C07:02       CSAPDWNNEQFF  20-1  2-1            CMV    IE-1
# 3     CRVLCCYVL   C07:02        CASSFPDTQYF    28  2-3            CMV    IE-1
# 4     CRVLCCYVL   C07:02       CASTPWGAEAFF    28  1-1            CMV    IE-1
# ..          ...      ...                ...   ...  ...            ...     ...
# 155  TPRVTGGGAM   B07:02  CASSSRFEGAFEMEQFF   7-9  2-1            CMV    pp65
# 156  TPRVTGGGAM   B07:02   CASSSRQGFTTGELFF   7-9  2-2            CMV    pp65
# 157  TPRVTGGGAM   B07:02  CASSTHDRAGANSPLHF   7-9  1-6            CMV    pp65
# 158  TPRVTGGGAM   B07:02   CASSVHDRGLGTEAFF   7-9  1-1            CMV    pp65
# 159  TPRVTGGGAM   B07:02  CASTDHDSGGVGTEAFF   7-9  1-1            CMV    pp65
#
# ...

# %%
huth_merged.to_csv("../../../data/processed/huth_input.csv.gz", index=False)

# %%
huth_merged.duplicated().value_counts()
# Out:
# False    1052
# dtype: int64
