# %%
import pandas as pd
import os

# %%
malekzadeh = pd.read_csv("../../../data/original/malekzadeh_original.csv.gz", index_col=False)

# %%
malekzadeh = malekzadeh[["Patient", "TCR name", "p53 mut", "HLA", "CDR3a", "CDR3b"]]

# %%
malekzadeh
# Out:
#    Patient      TCR name p53 mut         HLA               CDR3a  \
# 0        1   4141-TCR1a2   R175H     A*02:01  CAASKSAIMVVLQTSSSL
# 1        4     4285-TCR1   R175H  DRB1*13:01       CALITGGGNKLTF
# 2        5   4259-F6-TCR   Y220C  DRB1*04:01      CAWNSGGSNYKLTF
# 3        6  4149-TCRa2b2   Y220C  DRB3*02:02        CAVRVWDYKLSF
# 4        7     4127-TCR1   G245S  DRB3*02:02         CAVKGDYKLSF
# 5        9     4266-TCR2   R248W     A*68:01        CAVYTGGFKTIF
# 6        9     4266-TCR3   R248W     A*68:01      CAFYYGGSQGNLIF
# 7        9     4266-TCR4   R248W     A*68:01      CAVYPGGSQGNLIF
# 8       10   4273-TCR1a2   R248W  DPB1*02:01      CAVTLSGGYNKLIF
#
#              CDR3b
# 0   CASSIQQGADTQYF
# 1   CASRLQGWNSPLHF
# 2  CASSYSQAWGQPQHF
# 3   CASSISAGGDGYTF
# 4     CASSLVNTEAFF
# 5  CASNLGGGSTDTQYF
# 6  CASSFGSGSTDTQYF
# 7  CASSLGTGSTDTQYF
# 8     CASSSRDYEQYF

# %%
malekzadeh["HLA"] = malekzadeh["HLA"].str.replace("*","")
# Out:
# /tmp/ipykernel_374927/1798532162.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   malekzadeh["HLA"] = malekzadeh["HLA"].str.replace("*","")

# %%
malekzadeh["peptide_seq"] =""

# %%
malekzadeh["peptide_seq"][(malekzadeh["p53 mut"] == "R175H") & (malekzadeh["HLA"] == "A02:01")] = "HMTEVVRHC"
malekzadeh["peptide_seq"][(malekzadeh["p53 mut"] == "R175H") & (malekzadeh["HLA"] == "DRB113:01")] = "VVRHCPHHERCSDSDQHMTEVVRHCPHHER"
malekzadeh["peptide_seq"][(malekzadeh["p53 mut"] == "Y220C") & (malekzadeh["HLA"] == "DRB104:01")] = "RNTFRHSVVVPCE"
malekzadeh["peptide_seq"][(malekzadeh["p53 mut"] == "Y220C") & (malekzadeh["HLA"] == "DRB302:02")] = "NTFRHSVVVPCEPPE"
malekzadeh["peptide_seq"][(malekzadeh["p53 mut"] == "G245S") & (malekzadeh["HLA"] == "DRB302:02")] = "HYNYMCNSSCMGSMN"
malekzadeh["peptide_seq"][(malekzadeh["p53 mut"] == "R248W") & (malekzadeh["HLA"] == "A68:01")] = "SSCMGGMNWR"
malekzadeh["peptide_seq"][(malekzadeh["p53 mut"] == "R248W") & (malekzadeh["HLA"] == "DPB102:01")] = "SCMGGMNWRPILTII"
# Out:
# /tmp/ipykernel_374927/3353068142.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   malekzadeh["peptide_seq"][(malekzadeh["p53 mut"] == "R175H") & (malekzadeh["HLA"] == "A02:01")] = "HMTEVVRHC"
# /tmp/ipykernel_374927/3353068142.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   malekzadeh["peptide_seq"][(malekzadeh["p53 mut"] == "R175H") & (malekzadeh["HLA"] == "DRB113:01")] = "VVRHCPHHERCSDSDQHMTEVVRHCPHHER"
# /tmp/ipykernel_374927/3353068142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
malekzadeh["peptide_source"] = "epithelial cancer"
malekzadeh["tcr_source_organism"] = "human"
malekzadeh["experiment_type"] = "TCR seq"
malekzadeh["tissue"] = "TIL"
malekzadeh["protein"] = "p53"
malekzadeh["dataset"] = "Malekzadeh"

# %%
malekzadeh
# Out:
#    Patient      TCR name p53 mut        HLA               CDR3a  \
# 0        1   4141-TCR1a2   R175H     A02:01  CAASKSAIMVVLQTSSSL
# 1        4     4285-TCR1   R175H  DRB113:01       CALITGGGNKLTF
# 2        5   4259-F6-TCR   Y220C  DRB104:01      CAWNSGGSNYKLTF
# 3        6  4149-TCRa2b2   Y220C  DRB302:02        CAVRVWDYKLSF
# 4        7     4127-TCR1   G245S  DRB302:02         CAVKGDYKLSF
# 5        9     4266-TCR2   R248W     A68:01        CAVYTGGFKTIF
# 6        9     4266-TCR3   R248W     A68:01      CAFYYGGSQGNLIF
# 7        9     4266-TCR4   R248W     A68:01      CAVYPGGSQGNLIF
# 8       10   4273-TCR1a2   R248W  DPB102:01      CAVTLSGGYNKLIF
#
#              CDR3b                     peptide_seq     peptide_source  \
# 0   CASSIQQGADTQYF                       HMTEVVRHC  epithelial cancer
# 1   CASRLQGWNSPLHF  VVRHCPHHERCSDSDQHMTEVVRHCPHHER  epithelial cancer
# 2  CASSYSQAWGQPQHF                   RNTFRHSVVVPCE  epithelial cancer
# ...

# %%
malekzadeh = malekzadeh.rename(columns={"Patient":"patient", "HLA":"HLA_type"})

# %%
malekzadeh = malekzadeh[["peptide_seq", "HLA_type", "CDR3a", "CDR3b", "peptide_source", "protein", "tcr_source_organism", "patient", "tissue", "experiment_type", "dataset"]]

# %%
malekzadeh
# Out:
#                       peptide_seq   HLA_type               CDR3a  \
# 0                       HMTEVVRHC     A02:01  CAASKSAIMVVLQTSSSL
# 1  VVRHCPHHERCSDSDQHMTEVVRHCPHHER  DRB113:01       CALITGGGNKLTF
# 2                   RNTFRHSVVVPCE  DRB104:01      CAWNSGGSNYKLTF
# 3                 NTFRHSVVVPCEPPE  DRB302:02        CAVRVWDYKLSF
# 4                 HYNYMCNSSCMGSMN  DRB302:02         CAVKGDYKLSF
# 5                      SSCMGGMNWR     A68:01        CAVYTGGFKTIF
# 6                      SSCMGGMNWR     A68:01      CAFYYGGSQGNLIF
# 7                      SSCMGGMNWR     A68:01      CAVYPGGSQGNLIF
# 8                 SCMGGMNWRPILTII  DPB102:01      CAVTLSGGYNKLIF
#
#              CDR3b     peptide_source protein tcr_source_organism  patient  \
# 0   CASSIQQGADTQYF  epithelial cancer     p53               human        1
# 1   CASRLQGWNSPLHF  epithelial cancer     p53               human        4
# 2  CASSYSQAWGQPQHF  epithelial cancer     p53               human        5
# ...

# %%
malekzadeh.to_csv("../../../data/processed/malekzadeh_input.csv.gz", index=False)
