# %% [markdown]
# Read libraries and table with peptides from all experiments

# %%
import pandas as pd
import numpy as np

# %%
ST1 = pd.read_csv("../../../data/processed/zhang/Zhang_ST1_processed.csv.gz", index_col=0)

# %%
ST1.head()
# Out:
#   peptide_name peptide_seq tetramer_fluorescence  no_experiment HLA_type
# 0  NYESO1-V165   SLLMWITQV                    PE              1   A02:01
# 1      ADI-SVA   SVASTITGV                    PE              1   A02:01
# 2       BRA-AG   WLLPGTSTV                    PE              1   A02:01
# 3       BRA-NA   WLLPGTSTL                    PE              1   A02:01
# 4      CD1-LLG   LLGATCMFV                    PE              1   A02:01

# %% [markdown]
# The top 5 ranked peptides by MID count that are classified as positively binding are listed. An identity of "0" indicates that no positively binding peptide was found.
# A molecular identifier (MID) was included in the DNA-BC to
# provide absolute counting of the copy number for each species of tetram-
# ers bound to the cell

# %% [markdown]
# <b>ST2 - Experiment 1

# %%
ST2 = pd.read_excel("../../../data/original/zhang/ST2.xlsx")

# %%
new_columns = ["Cell Name", "Sorted Population", "rank_1", "rank_2", "rank_3", "rank_4", "rank_5","TRAV1", "CDR3α,1", "TRAV2", "CDR3α,2", "TRBV", "CDR3β"]

# %%
ST2.columns = new_columns

# %%
ST2 = ST2.iloc[2:, :].reset_index(drop=True)

# %%
ST2
# Out:
#     Cell Name Sorted Population     rank_1   rank_2      rank_3      rank_4  \
# 0         AA1  Naïve Endogenous   ZNT8-LLS        0           0           0
# 1        AA10  Naïve Endogenous  MART1-A2L        0           0           0
# 2        AA11  Naïve Endogenous  MART1-A2L        0           0           0
# 3        AA12  Naïve Endogenous  MART1-A2L        0           0           0
# 4         AA2  Naïve Endogenous  MART1-A2L        0           0           0
# ..        ...               ...        ...      ...         ...         ...
# 170       BH4          Spike-In    HCV-K1Y  HCV-L2I     HCV-K1S  HCV-K1Y17V
# 171       BH5          Spike-In    HCV-K1Y  HCV-L2I  HCV-K1Y17V     HCV-K1S
# 172       BH6          Spike-In    HCV-K1Y  HCV-L2I     HCV-K1S  HCV-K1Y17V
# 173       BH7          Spike-In    HCV-K1Y  HCV-L2I  HCV-K1Y17V     HCV-K1S
# 174       BH8          Spike-In    HCV-K1Y  HCV-L2I  HCV-K1Y17V     HCV-K1S
#
#       rank_5        TRAV1         CDR3α,1 TRAV2 CDR3α,2           TRBV  \
# 0          0          NaN             NaN   NaN     NaN  6-2*01,6-3*01
# 1          0      12-2*01     CGGQAGTALIF   NaN     NaN         6-1*01
# 2          0      12-2*01     CAVNGGNQFYF   NaN     NaN          28*01
# 3          0      12-2*01     CAVGRDDKIIF   NaN     NaN         7-2*01
# 4          0        17*01   CATCMDSNYQLIW   NaN     NaN          15*01
# ..       ...          ...             ...   ...     ...            ...
# 170  HCV-KLV  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN          28*01
# 171  HCV-KLV  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN          28*01
# 172  HCV-KLV  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN          28*01
# 173  HCV-KLV  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN          28*01
# 174  HCV-KLV  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN          28*01
#
#                  CDR3β
# 0         CASSYSENEQFF
# 1      CASRSYVASSNEQFF
# 2      CASTQWYGGGTPPYF
# 3     CASSLTTGVFSQPQHF
# 4    CATSPYSVTTFANTIYF
# ..                 ...
# 170    CASSFLGTGLNEQYF
# 171    CASSFLGTGLNEQYF
# 172    CASSFLGTGLNEQYF
# 173    CASSFLGTGLNEQYF
# 174    CASSFLGTGLNEQYF
#
# [175 rows x 13 columns]

# %% [markdown]
# Merging peptides from each rank to create one column. Adding a flag of rank number.

# %%
remaining_cols = [col for col in ST2.columns if col not in ["rank_1", "rank_2", "rank_3", "rank_4", "rank_5"]]
remaining_cols
# Out:
# ['Cell Name',
#  'Sorted Population',
#  'TRAV1',
#  'CDR3α,1',
#  'TRAV2',
#  'CDR3α,2',
#  'TRBV',
#  'CDR3β']

# %%
ST2 = ST2.melt(id_vars=remaining_cols, value_vars=["rank_1", "rank_2", "rank_3", "rank_4", "rank_5"], value_name='peptide_name')

# %%
ST2 = ST2.rename(columns={'variable':'peptide_rank'})

# %%
ST2.columns
# Out:
# Index(['Cell Name', 'Sorted Population', 'TRAV1', 'CDR3α,1', 'TRAV2',
#        'CDR3α,2', 'TRBV', 'CDR3β', 'peptide_rank', 'peptide_name'],
#       dtype='object')

# %%
ST2["no_experiment"] = "1"

# %%
ST2 = ST2.astype({"no_experiment": "int64"})

# %%
Exp1 = ST2.merge(ST1, on = ["peptide_name", "no_experiment"])

# %%
Exp1
# Out:
#     Cell Name Sorted Population        TRAV1         CDR3α,1 TRAV2 CDR3α,2  \
# 0         AA1  Naïve Endogenous          NaN             NaN   NaN     NaN
# 1        AB12  Naïve Endogenous      12-3*01     CAAGGSYIPTF   NaN     NaN
# 2        AA10  Naïve Endogenous      12-2*01     CGGQAGTALIF   NaN     NaN
# 3        AA11  Naïve Endogenous      12-2*01     CAVNGGNQFYF   NaN     NaN
# 4        AA12  Naïve Endogenous      12-2*01     CAVGRDDKIIF   NaN     NaN
# ..        ...               ...          ...             ...   ...     ...
# 194       BH2          Spike-In  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN
# 195       BH3          Spike-In  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN
# 196       BH5          Spike-In  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN
# 197       BH7          Spike-In  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN
# 198       BH8          Spike-In  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN
#
#               TRBV              CDR3β peptide_rank peptide_name  \
# 0    6-2*01,6-3*01       CASSYSENEQFF       rank_1     ZNT8-LLS
# 1            28*01  CASSGTGGYSGANVLTF       rank_1     ZNT8-LLS
# 2           6-1*01    CASRSYVASSNEQFF       rank_1    MART1-A2L
# 3            28*01    CASTQWYGGGTPPYF       rank_1    MART1-A2L
# 4           7-2*01   CASSLTTGVFSQPQHF       rank_1    MART1-A2L
# ..             ...                ...          ...          ...
# 194          28*01    CASSFLGTGLNEQYF       rank_4      HCV-K1S
# 195          28*01    CASSFLGTGLNEQYF       rank_4      HCV-K1S
# 196          28*01    CASSFLGTGLNEQYF       rank_4      HCV-K1S
# 197          28*01    CASSFLGTGLNEQYF       rank_4      HCV-K1S
# 198          28*01    CASSFLGTGLNEQYF       rank_4      HCV-K1S
#
#      no_experiment peptide_seq tetramer_fluorescence HLA_type
# 0                1   LLSLFSLWL                    PE   A02:01
# 1                1   LLSLFSLWL                    PE   A02:01
# 2                1  ELAGIGILTV                    PE   A02:01
# 3                1  ELAGIGILTV                    PE   A02:01
# 4                1  ELAGIGILTV                    PE   A02:01
# ..             ...         ...                   ...      ...
# 194              1  SLVALGINAV                   APC   A02:01
# 195              1  SLVALGINAV                   APC   A02:01
# 196              1  SLVALGINAV                   APC   A02:01
# 197              1  SLVALGINAV                   APC   A02:01
# 198              1  SLVALGINAV                   APC   A02:01
#
# [199 rows x 14 columns]

# %%
Exp1 = Exp1.rename(columns={"Cell Name": "cell_name", "Sorted Population": "sorted_population", "CDR3α,1": "CDR3alpha_1", "CDR3α,2":"CDR3alpha_2", "CDR3β": "CDR3beta"})

# %% [markdown]
# Mam dwa warianty łańcucha TRAV -> chce zrobić z tego wiersze

# %%
remaining_cols = [col for col in Exp1.columns if col not in ['TRAV1', 'TRAV2', 'CDR3alpha_1', 'CDR3alpha_2']]
remaining_cols
# Out:
# ['cell_name',
#  'sorted_population',
#  'TRBV',
#  'CDR3beta',
#  'peptide_rank',
#  'peptide_name',
#  'no_experiment',
#  'peptide_seq',
#  'tetramer_fluorescence',
#  'HLA_type']

# %%
Exp1.cell_name.duplicated().sum()
# Out:
# 27

# %%
Exp1_trav = Exp1.melt(id_vars=remaining_cols, value_vars=['TRAV1', 'TRAV2'], value_name='TRAV')
Exp1_trav
# Out:
#     cell_name sorted_population           TRBV           CDR3beta  \
# 0         AA1  Naïve Endogenous  6-2*01,6-3*01       CASSYSENEQFF
# 1        AB12  Naïve Endogenous          28*01  CASSGTGGYSGANVLTF
# 2        AA10  Naïve Endogenous         6-1*01    CASRSYVASSNEQFF
# 3        AA11  Naïve Endogenous          28*01    CASTQWYGGGTPPYF
# 4        AA12  Naïve Endogenous         7-2*01   CASSLTTGVFSQPQHF
# ..        ...               ...            ...                ...
# 393       BH2          Spike-In          28*01    CASSFLGTGLNEQYF
# 394       BH3          Spike-In          28*01    CASSFLGTGLNEQYF
# 395       BH5          Spike-In          28*01    CASSFLGTGLNEQYF
# 396       BH7          Spike-In          28*01    CASSFLGTGLNEQYF
# 397       BH8          Spike-In          28*01    CASSFLGTGLNEQYF
#
#     peptide_rank peptide_name  no_experiment peptide_seq  \
# 0         rank_1     ZNT8-LLS              1   LLSLFSLWL
# 1         rank_1     ZNT8-LLS              1   LLSLFSLWL
# 2         rank_1    MART1-A2L              1  ELAGIGILTV
# 3         rank_1    MART1-A2L              1  ELAGIGILTV
# 4         rank_1    MART1-A2L              1  ELAGIGILTV
# ..           ...          ...            ...         ...
# 393       rank_4      HCV-K1S              1  SLVALGINAV
# 394       rank_4      HCV-K1S              1  SLVALGINAV
# 395       rank_4      HCV-K1S              1  SLVALGINAV
# 396       rank_4      HCV-K1S              1  SLVALGINAV
# 397       rank_4      HCV-K1S              1  SLVALGINAV
#
#     tetramer_fluorescence HLA_type variable     TRAV
# 0                      PE   A02:01    TRAV1      NaN
# 1                      PE   A02:01    TRAV1  12-3*01
# 2                      PE   A02:01    TRAV1  12-2*01
# 3                      PE   A02:01    TRAV1  12-2*01
# 4                      PE   A02:01    TRAV1  12-2*01
# ..                    ...      ...      ...      ...
# 393                   APC   A02:01    TRAV2      NaN
# 394                   APC   A02:01    TRAV2      NaN
# 395                   APC   A02:01    TRAV2      NaN
# 396                   APC   A02:01    TRAV2      NaN
# 397                   APC   A02:01    TRAV2      NaN
#
# [398 rows x 12 columns]

# %%
Exp1_cdr3alpha = Exp1.melt(id_vars=remaining_cols, value_vars=['CDR3alpha_1', 'CDR3alpha_2'], value_name='CDR3alpha')
Exp1_cdr3alpha
# Out:
#     cell_name sorted_population           TRBV           CDR3beta  \
# 0         AA1  Naïve Endogenous  6-2*01,6-3*01       CASSYSENEQFF
# 1        AB12  Naïve Endogenous          28*01  CASSGTGGYSGANVLTF
# 2        AA10  Naïve Endogenous         6-1*01    CASRSYVASSNEQFF
# 3        AA11  Naïve Endogenous          28*01    CASTQWYGGGTPPYF
# 4        AA12  Naïve Endogenous         7-2*01   CASSLTTGVFSQPQHF
# ..        ...               ...            ...                ...
# 393       BH2          Spike-In          28*01    CASSFLGTGLNEQYF
# 394       BH3          Spike-In          28*01    CASSFLGTGLNEQYF
# 395       BH5          Spike-In          28*01    CASSFLGTGLNEQYF
# 396       BH7          Spike-In          28*01    CASSFLGTGLNEQYF
# 397       BH8          Spike-In          28*01    CASSFLGTGLNEQYF
#
#     peptide_rank peptide_name  no_experiment peptide_seq  \
# 0         rank_1     ZNT8-LLS              1   LLSLFSLWL
# 1         rank_1     ZNT8-LLS              1   LLSLFSLWL
# 2         rank_1    MART1-A2L              1  ELAGIGILTV
# 3         rank_1    MART1-A2L              1  ELAGIGILTV
# 4         rank_1    MART1-A2L              1  ELAGIGILTV
# ..           ...          ...            ...         ...
# 393       rank_4      HCV-K1S              1  SLVALGINAV
# 394       rank_4      HCV-K1S              1  SLVALGINAV
# 395       rank_4      HCV-K1S              1  SLVALGINAV
# 396       rank_4      HCV-K1S              1  SLVALGINAV
# 397       rank_4      HCV-K1S              1  SLVALGINAV
#
#     tetramer_fluorescence HLA_type     variable    CDR3alpha
# 0                      PE   A02:01  CDR3alpha_1          NaN
# 1                      PE   A02:01  CDR3alpha_1  CAAGGSYIPTF
# 2                      PE   A02:01  CDR3alpha_1  CGGQAGTALIF
# 3                      PE   A02:01  CDR3alpha_1  CAVNGGNQFYF
# 4                      PE   A02:01  CDR3alpha_1  CAVGRDDKIIF
# ..                    ...      ...          ...          ...
# 393                   APC   A02:01  CDR3alpha_2          NaN
# 394                   APC   A02:01  CDR3alpha_2          NaN
# 395                   APC   A02:01  CDR3alpha_2          NaN
# 396                   APC   A02:01  CDR3alpha_2          NaN
# 397                   APC   A02:01  CDR3alpha_2          NaN
#
# [398 rows x 12 columns]

# %%
Exp1_trav.drop(columns=['variable'], inplace=True)
Exp1_cdr3alpha.drop(columns=['variable'], inplace=True)

# %%
assert (Exp1_trav.cell_name == Exp1_cdr3alpha.cell_name).all()

# %%
Exp1_final = pd.concat([Exp1_trav,Exp1_cdr3alpha['CDR3alpha']], axis=1)
Exp1_final
# Out:
#     cell_name sorted_population           TRBV           CDR3beta  \
# 0         AA1  Naïve Endogenous  6-2*01,6-3*01       CASSYSENEQFF
# 1        AB12  Naïve Endogenous          28*01  CASSGTGGYSGANVLTF
# 2        AA10  Naïve Endogenous         6-1*01    CASRSYVASSNEQFF
# 3        AA11  Naïve Endogenous          28*01    CASTQWYGGGTPPYF
# 4        AA12  Naïve Endogenous         7-2*01   CASSLTTGVFSQPQHF
# ..        ...               ...            ...                ...
# 393       BH2          Spike-In          28*01    CASSFLGTGLNEQYF
# 394       BH3          Spike-In          28*01    CASSFLGTGLNEQYF
# 395       BH5          Spike-In          28*01    CASSFLGTGLNEQYF
# 396       BH7          Spike-In          28*01    CASSFLGTGLNEQYF
# 397       BH8          Spike-In          28*01    CASSFLGTGLNEQYF
#
#     peptide_rank peptide_name  no_experiment peptide_seq  \
# 0         rank_1     ZNT8-LLS              1   LLSLFSLWL
# 1         rank_1     ZNT8-LLS              1   LLSLFSLWL
# 2         rank_1    MART1-A2L              1  ELAGIGILTV
# 3         rank_1    MART1-A2L              1  ELAGIGILTV
# 4         rank_1    MART1-A2L              1  ELAGIGILTV
# ..           ...          ...            ...         ...
# 393       rank_4      HCV-K1S              1  SLVALGINAV
# 394       rank_4      HCV-K1S              1  SLVALGINAV
# 395       rank_4      HCV-K1S              1  SLVALGINAV
# 396       rank_4      HCV-K1S              1  SLVALGINAV
# 397       rank_4      HCV-K1S              1  SLVALGINAV
#
#     tetramer_fluorescence HLA_type     TRAV    CDR3alpha
# 0                      PE   A02:01      NaN          NaN
# 1                      PE   A02:01  12-3*01  CAAGGSYIPTF
# 2                      PE   A02:01  12-2*01  CGGQAGTALIF
# 3                      PE   A02:01  12-2*01  CAVNGGNQFYF
# 4                      PE   A02:01  12-2*01  CAVGRDDKIIF
# ..                    ...      ...      ...          ...
# 393                   APC   A02:01      NaN          NaN
# 394                   APC   A02:01      NaN          NaN
# 395                   APC   A02:01      NaN          NaN
# 396                   APC   A02:01      NaN          NaN
# 397                   APC   A02:01      NaN          NaN
#
# [398 rows x 12 columns]

# %% [markdown]
# Tutaj sprawdzamy w obrębie remaining_cols czy mamy jakieś duplikaty. Potem sprawdzamy czy gdzieś występuje NaN zestaw TRAV & CDR3alpha.

# %% [markdown]
# Interesują nas oryginały puste, oryginały pełne, oraz duplikaty pełne.

# %%
mask_remaining = Exp1_final.duplicated(subset=remaining_cols)
mask_melted = Exp1_final[['TRAV', 'CDR3alpha']].isna().all(axis=1)

mask_redundant = mask_remaining & mask_melted

Exp1_final = Exp1_final[~(mask_remaining & mask_melted).values]
Exp1_final
# Out:
#     cell_name     sorted_population           TRBV           CDR3beta  \
# 0         AA1      Naïve Endogenous  6-2*01,6-3*01       CASSYSENEQFF
# 1        AB12      Naïve Endogenous          28*01  CASSGTGGYSGANVLTF
# 2        AA10      Naïve Endogenous         6-1*01    CASRSYVASSNEQFF
# 3        AA11      Naïve Endogenous          28*01    CASTQWYGGGTPPYF
# 4        AA12      Naïve Endogenous         7-2*01   CASSLTTGVFSQPQHF
# ..        ...                   ...            ...                ...
# 255      BF11  Non-Naïve Endogenous            NaN                NaN
# 256      BF12  Non-Naïve Endogenous            NaN                NaN
# 269       AC2      Naïve Endogenous          18*01   CASSSRDRSSSTEAFF
# 279       BB7         Naïve Foreign        20-1*01     CSARGAGVPYEQYF
# 380       AC2      Naïve Endogenous          18*01   CASSSRDRSSSTEAFF
#
#     peptide_rank peptide_name  no_experiment peptide_seq  \
# 0         rank_1     ZNT8-LLS              1   LLSLFSLWL
# 1         rank_1     ZNT8-LLS              1   LLSLFSLWL
# 2         rank_1    MART1-A2L              1  ELAGIGILTV
# 3         rank_1    MART1-A2L              1  ELAGIGILTV
# 4         rank_1    MART1-A2L              1  ELAGIGILTV
# ..           ...          ...            ...         ...
# 255       rank_1    MART1-A2L              1  ELAGIGILTV
# 256       rank_1    MART1-A2L              1  ELAGIGILTV
# 269       rank_1    GP100-IMD              1   IMDQVPFSV
# 279       rank_1      CMV-MLN              1   MLNIPSINV
# 380       rank_2    GP100-ITD              1   ITDQVPFSV
#
#     tetramer_fluorescence HLA_type         TRAV         CDR3alpha
# 0                      PE   A02:01          NaN               NaN
# 1                      PE   A02:01      12-3*01       CAAGGSYIPTF
# 2                      PE   A02:01      12-2*01       CGGQAGTALIF
# 3                      PE   A02:01      12-2*01       CAVNGGNQFYF
# 4                      PE   A02:01      12-2*01       CAVGRDDKIIF
# ..                    ...      ...          ...               ...
# 255                    PE   A02:01  38-2/DV8*01    CAYRSPPSSEKLVF
# 256                    PE   A02:01        30*01     CGTLRNNNARLMF
# 269                    PE   A02:01        16*01    CALSPGYNFNKFYF
# 279                   APC   A02:01       8-4*01  CAVSSITQGGSEKLVF
# 380                    PE   A02:01        16*01    CALSPGYNFNKFYF
#
# [206 rows x 12 columns]

# %%
Exp1_final["TRAV"].unique()
# Out:
# array([nan, '12-3*01', '12-2*01', '17*01', '23/DV6*01', '13-2*01',
#        '41*01', '16*01', '13-1*01', '8-1*01', '26-1*01', '8-4*01',
#        '38-2/DV8*01', '29/DV5*01', '24*01', '12-1*01', '8-3*01', '27*01',
#        '30*01', '3*01', '35*01', '*'], dtype=object)

# %%
Exp1_final["TRBV"].unique()
# Out:
# array(['6-2*01,6-3*01', '28*01', '6-1*01', '7-2*01', '15*01', '4-2*01',
#        '2*01', nan, '4-1*01', '27*01', '20-1*01', '19*01', '6-6*01',
#        '14*01', '6-5*01', '11-1*01', '5-6*01', '6-4*01',
#        '12-3*01,12-4*01', '18*01', '9*01', '4-3*01', '25-1*01', '10-3*01',
#        '3-1*01', '29-1*01'], dtype=object)

# %%
Exp1_final = Exp1_final[Exp1_final["TRAV"]!="*"]

# %%
Exp1_final = Exp1_final.reset_index(drop=True)

# %%
Exp1_final.to_csv("../../../data/processed/zhang/Exp1_merged.csv.gz")

# %% [markdown]
# <b>ST3 - Experiment 2

# %%
ST3 = pd.read_excel("../../../data/original/zhang/ST3.xlsx")

# %%
new_columns = ["Cell Name", "Sorted Population", "rank_1", "rank_2", "rank_3", "rank_4", "rank_5" ,"TRAV1", "CDR3α,1", "TRAV2", "CDR3α,2", "TRBV", "CDR3β"]

# %%
ST3.columns = new_columns

# %%
ST3 = ST3.iloc[2:, :].reset_index(drop=True)

# %%
ST3
# Out:
#     Cell Name Sorted Population     rank_1   rank_2   rank_3      rank_4  \
# 0        WA11             Clone    HCV_K1Y  HCV_L2I  HCV_K1S  HCV_K1Y17V
# 1        WB11             Clone    HCV_K1Y  HCV_L2I  HCV_K1S  HCV_K1Y17V
# 2        WC11             Clone    HCV_K1Y  HCV_K1S  HCV_L2I  HCV_K1Y17V
# 3        WD11             Clone          0        0        0           0
# 4        WE11             Clone    HCV_K1Y  HCV_L2I  HCV_K1S  HCV_K1Y17V
# ..        ...               ...        ...      ...      ...         ...
# 371       WF9     Self_Nonnaive  MART1_A2L        0        0           0
# 372      WG10     Self_Nonnaive   DRIP_MLY        0        0           0
# 373       WG9     Self_Nonnaive  MART1_A2L        0        0           0
# 374      WH10     Self_Nonnaive          0        0        0           0
# 375       WH9     Self_Nonnaive  MART1_A2L        0        0           0
#
#       rank_5     TRAV1            CDR3α,1 TRAV2 CDR3α,2       TRBV  \
# 0    HCV_KLV  38-2/DV8     CAYRSPPSSEKLVF   NaN     NaN         28
# 1    HCV_KLV  38-2/DV8     CAYRSPPSSEKLVF   NaN     NaN         28
# 2    HCV_KLV  38-2/DV8     CAYRSPPSSEKLVF   NaN     NaN         28
# 3          0       NaN                NaN   NaN     NaN        NaN
# 4    HCV_KLV  38-2/DV8     CAYRSPPSSEKLVF   NaN     NaN         28
# ..       ...       ...                ...   ...     ...        ...
# 371        0    14/DV4     CAMREGTGRRALTF   NaN     NaN    6-2,6-3
# 372        0       NaN                NaN   NaN     NaN  12-3,12-4
# 373        0    14/DV4     CAMREGTGRRALTF   NaN     NaN    6-2,6-3
# 374        0    14/DV4  CAMREGPGGTSYGKLTF   NaN     NaN    6-2,6-3
# 375        0       NaN                NaN   NaN     NaN    6-2,6-3
#
#                  CDR3β
# 0      CASSFLGTGLNEQYF
# 1      CASSFLGTGLNEQYF
# 2      CASSFLGTGLNEQYF
# 3                  NaN
# 4      CASSFLGTGLNEQYF
# ..                 ...
# 371    CASSYFGGSLSEQYF
# 372  CASSFGRNRSQNTEAFF
# 373    CASSYFGGSLSEQYF
# 374    CASSYRQDSNQPQHF
# 375    CASSYFGGSLSEQYF
#
# [376 rows x 13 columns]

# %%
remaining_cols = [col for col in ST3.columns if col not in ["rank_1", "rank_2", "rank_3", "rank_4", "rank_5"]]
remaining_cols
# Out:
# ['Cell Name',
#  'Sorted Population',
#  'TRAV1',
#  'CDR3α,1',
#  'TRAV2',
#  'CDR3α,2',
#  'TRBV',
#  'CDR3β']

# %%
ST3 = ST3.melt(id_vars=remaining_cols, value_vars=["rank_1", "rank_2", "rank_3", "rank_4", "rank_5"], value_name='peptide_name')

# %%
ST3 = ST3.rename(columns={'variable':'peptide_rank'})

# %%
ST3.columns
# Out:
# Index(['Cell Name', 'Sorted Population', 'TRAV1', 'CDR3α,1', 'TRAV2',
#        'CDR3α,2', 'TRBV', 'CDR3β', 'peptide_rank', 'peptide_name'],
#       dtype='object')

# %%
ST3["no_experiment"] = "2"

# %%
ST3 = ST3.astype({"no_experiment": "int64"})

# %%
ST3 = ST3[~(ST3["peptide_name"] == 0)]
ST3["peptide_name"] = ST3["peptide_name"].str.strip()

# %%
Experiment2  = ST1[ST1["no_experiment"]==2]

# %%
Experiment2
# Out:
#     peptide_name peptide_seq tetramer_fluorescence  no_experiment HLA_type
# 96   NYESO1-V165   SLLMWITQV                    PE              2   A02:01
# 97       ADI-SVA   SVASTITGV                    PE              2   A02:01
# 98        BRA-AG   WLLPGTSTV                    PE              2   A02:01
# 99        BRA-NA   WLLPGTSTL                    PE              2   A02:01
# 100      CD1-LLG   LLGATCMFV                    PE              2   A02:01
# ..           ...         ...                   ...            ...      ...
# 187      YFV-LLW   LLWNGPMAV                   APC              2   A02:01
# 188    ALADH-VLM  VLMGGVPGVE                   APC              2   A02:01
# 189     GLNS-GLL   GLLHHAPSL                   APC              2   A02:01
# 190     SODA-DMW   DMWEHAFYL                   APC              2   A02:01
# 191      HCV-A9N  KLVALGINNV                   APC              2   A02:01
#
# [96 rows x 5 columns]

# %%
ST3["peptide_name"].isin(Experiment2["peptide_name"]).value_counts()
# Out:
# False    410
# Name: peptide_name, dtype: int64

# %% [markdown]
# Nie pokrywają się! W ST3 używane są "_" w nazwach, natomiast w ST1 "-". Należy zamienić w ST3 wszystkie "_" na "-".

# %%
ST3["peptide_name"] = ST3["peptide_name"].replace("_", "-",regex=True)

# %%
ST3["peptide_name"]
# Out:
# 0       HCV-K1Y
# 1       HCV-K1Y
# 2       HCV-K1Y
# 4       HCV-K1Y
# 5       HCV-K1Y
#          ...
# 1506    HCV-KLV
# 1508    HCV-KLV
# 1509    HCV-KLV
# 1510    HCV-KLV
# 1511    HCV-KLV
# Name: peptide_name, Length: 410, dtype: object

# %%
Exp2 = ST3.merge(ST1, on = ["peptide_name", "no_experiment"])

# %%
Exp2
# Out:
#     Cell Name Sorted Population     TRAV1         CDR3α,1 TRAV2 CDR3α,2  TRBV  \
# 0        WA11             Clone  38-2/DV8  CAYRSPPSSEKLVF   NaN     NaN    28
# 1        WB11             Clone  38-2/DV8  CAYRSPPSSEKLVF   NaN     NaN    28
# 2        WC11             Clone  38-2/DV8  CAYRSPPSSEKLVF   NaN     NaN    28
# 3        WE11             Clone  38-2/DV8  CAYRSPPSSEKLVF   NaN     NaN    28
# 4        WF11             Clone  38-2/DV8  CAYRSPPSSEKLVF   NaN     NaN    28
# ..        ...               ...       ...             ...   ...     ...   ...
# 397      WC11             Clone  38-2/DV8  CAYRSPPSSEKLVF   NaN     NaN    28
# 398      WE11             Clone  38-2/DV8  CAYRSPPSSEKLVF   NaN     NaN    28
# 399      WG11             Clone  38-2/DV8  CAYRSPPSSEKLVF   NaN     NaN    28
# 400      WH11             Clone  38-2/DV8  CAYRSPPSSEKLVF   NaN     NaN    28
# 401       UB6        Self_Naive      12-2     CAVSSYDKVIF   NaN     NaN  20-1
#
#                CDR3β peptide_rank peptide_name  no_experiment peptide_seq  \
# 0    CASSFLGTGLNEQYF       rank_1      HCV-K1Y              2  YLVALGINAV
# 1    CASSFLGTGLNEQYF       rank_1      HCV-K1Y              2  YLVALGINAV
# 2    CASSFLGTGLNEQYF       rank_1      HCV-K1Y              2  YLVALGINAV
# 3    CASSFLGTGLNEQYF       rank_1      HCV-K1Y              2  YLVALGINAV
# 4    CASSFLGTGLNEQYF       rank_1      HCV-K1Y              2  YLVALGINAV
# ..               ...          ...          ...            ...         ...
# 397  CASSFLGTGLNEQYF       rank_4   HCV-K1Y17V              2  YLVALGVNAV
# 398  CASSFLGTGLNEQYF       rank_4   HCV-K1Y17V              2  YLVALGVNAV
# 399  CASSFLGTGLNEQYF       rank_4   HCV-K1Y17V              2  YLVALGVNAV
# 400  CASSFLGTGLNEQYF       rank_4   HCV-K1Y17V              2  YLVALGVNAV
# 401     CSALTGNQPQHF       rank_3      PPI-RLL              2   RLLPLLALL
#
#     tetramer_fluorescence HLA_type
# 0                     APC   A02:01
# 1                     APC   A02:01
# 2                     APC   A02:01
# 3                     APC   A02:01
# 4                     APC   A02:01
# ..                    ...      ...
# 397                   APC   A02:01
# 398                   APC   A02:01
# 399                   APC   A02:01
# 400                   APC   A02:01
# 401                    PE   A02:01
#
# [402 rows x 14 columns]

# %%
Exp2 = Exp2.rename(columns={"Cell Name": "cell_name", "Sorted Population": "sorted_population", "CDR3α,1": "CDR3alpha_1", "CDR3α,2":"CDR3alpha_2", "CDR3β": "CDR3beta"})

# %% [markdown]
# Mam dwa warianty łańcucha TRAV -> chce zrobić z tego wiersze

# %%
remaining_cols = [col for col in Exp2.columns if col not in ['TRAV1', 'TRAV2', 'CDR3alpha_1', 'CDR3alpha_2']]
remaining_cols
# Out:
# ['cell_name',
#  'sorted_population',
#  'TRBV',
#  'CDR3beta',
#  'peptide_rank',
#  'peptide_name',
#  'no_experiment',
#  'peptide_seq',
#  'tetramer_fluorescence',
#  'HLA_type']

# %%
Exp2.cell_name.duplicated().sum()
# Out:
# 60

# %%
Exp2_trav = Exp2.melt(id_vars=remaining_cols, value_vars=['TRAV1', 'TRAV2'], value_name='TRAV')
Exp2_trav
# Out:
#     cell_name sorted_population  TRBV         CDR3beta peptide_rank  \
# 0        WA11             Clone    28  CASSFLGTGLNEQYF       rank_1
# 1        WB11             Clone    28  CASSFLGTGLNEQYF       rank_1
# 2        WC11             Clone    28  CASSFLGTGLNEQYF       rank_1
# 3        WE11             Clone    28  CASSFLGTGLNEQYF       rank_1
# 4        WF11             Clone    28  CASSFLGTGLNEQYF       rank_1
# ..        ...               ...   ...              ...          ...
# 799      WC11             Clone    28  CASSFLGTGLNEQYF       rank_4
# 800      WE11             Clone    28  CASSFLGTGLNEQYF       rank_4
# 801      WG11             Clone    28  CASSFLGTGLNEQYF       rank_4
# 802      WH11             Clone    28  CASSFLGTGLNEQYF       rank_4
# 803       UB6        Self_Naive  20-1     CSALTGNQPQHF       rank_3
#
#     peptide_name  no_experiment peptide_seq tetramer_fluorescence HLA_type  \
# 0        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 1        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 2        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 3        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 4        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# ..           ...            ...         ...                   ...      ...
# 799   HCV-K1Y17V              2  YLVALGVNAV                   APC   A02:01
# 800   HCV-K1Y17V              2  YLVALGVNAV                   APC   A02:01
# 801   HCV-K1Y17V              2  YLVALGVNAV                   APC   A02:01
# 802   HCV-K1Y17V              2  YLVALGVNAV                   APC   A02:01
# 803      PPI-RLL              2   RLLPLLALL                    PE   A02:01
#
#     variable      TRAV
# 0      TRAV1  38-2/DV8
# 1      TRAV1  38-2/DV8
# 2      TRAV1  38-2/DV8
# 3      TRAV1  38-2/DV8
# 4      TRAV1  38-2/DV8
# ..       ...       ...
# 799    TRAV2       NaN
# 800    TRAV2       NaN
# 801    TRAV2       NaN
# 802    TRAV2       NaN
# 803    TRAV2       NaN
#
# [804 rows x 12 columns]

# %%
Exp2_cdr3alpha = Exp2.melt(id_vars=remaining_cols, value_vars=['CDR3alpha_1', 'CDR3alpha_2'], value_name='CDR3alpha')
Exp2_cdr3alpha
# Out:
#     cell_name sorted_population  TRBV         CDR3beta peptide_rank  \
# 0        WA11             Clone    28  CASSFLGTGLNEQYF       rank_1
# 1        WB11             Clone    28  CASSFLGTGLNEQYF       rank_1
# 2        WC11             Clone    28  CASSFLGTGLNEQYF       rank_1
# 3        WE11             Clone    28  CASSFLGTGLNEQYF       rank_1
# 4        WF11             Clone    28  CASSFLGTGLNEQYF       rank_1
# ..        ...               ...   ...              ...          ...
# 799      WC11             Clone    28  CASSFLGTGLNEQYF       rank_4
# 800      WE11             Clone    28  CASSFLGTGLNEQYF       rank_4
# 801      WG11             Clone    28  CASSFLGTGLNEQYF       rank_4
# 802      WH11             Clone    28  CASSFLGTGLNEQYF       rank_4
# 803       UB6        Self_Naive  20-1     CSALTGNQPQHF       rank_3
#
#     peptide_name  no_experiment peptide_seq tetramer_fluorescence HLA_type  \
# 0        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 1        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 2        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 3        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 4        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# ..           ...            ...         ...                   ...      ...
# 799   HCV-K1Y17V              2  YLVALGVNAV                   APC   A02:01
# 800   HCV-K1Y17V              2  YLVALGVNAV                   APC   A02:01
# 801   HCV-K1Y17V              2  YLVALGVNAV                   APC   A02:01
# 802   HCV-K1Y17V              2  YLVALGVNAV                   APC   A02:01
# 803      PPI-RLL              2   RLLPLLALL                    PE   A02:01
#
#         variable       CDR3alpha
# 0    CDR3alpha_1  CAYRSPPSSEKLVF
# 1    CDR3alpha_1  CAYRSPPSSEKLVF
# 2    CDR3alpha_1  CAYRSPPSSEKLVF
# 3    CDR3alpha_1  CAYRSPPSSEKLVF
# 4    CDR3alpha_1  CAYRSPPSSEKLVF
# ..           ...             ...
# 799  CDR3alpha_2             NaN
# 800  CDR3alpha_2             NaN
# 801  CDR3alpha_2             NaN
# 802  CDR3alpha_2             NaN
# 803  CDR3alpha_2             NaN
#
# [804 rows x 12 columns]

# %%
Exp2_trav.drop(columns=['variable'], inplace=True)
Exp2_cdr3alpha.drop(columns=['variable'], inplace=True)

# %%
assert (Exp2_trav.cell_name == Exp2_cdr3alpha.cell_name).all()

# %%
Exp2_final = pd.concat([Exp2_trav,Exp2_cdr3alpha['CDR3alpha']], axis=1)
Exp2_final
# Out:
#     cell_name sorted_population  TRBV         CDR3beta peptide_rank  \
# 0        WA11             Clone    28  CASSFLGTGLNEQYF       rank_1
# 1        WB11             Clone    28  CASSFLGTGLNEQYF       rank_1
# 2        WC11             Clone    28  CASSFLGTGLNEQYF       rank_1
# 3        WE11             Clone    28  CASSFLGTGLNEQYF       rank_1
# 4        WF11             Clone    28  CASSFLGTGLNEQYF       rank_1
# ..        ...               ...   ...              ...          ...
# 799      WC11             Clone    28  CASSFLGTGLNEQYF       rank_4
# 800      WE11             Clone    28  CASSFLGTGLNEQYF       rank_4
# 801      WG11             Clone    28  CASSFLGTGLNEQYF       rank_4
# 802      WH11             Clone    28  CASSFLGTGLNEQYF       rank_4
# 803       UB6        Self_Naive  20-1     CSALTGNQPQHF       rank_3
#
#     peptide_name  no_experiment peptide_seq tetramer_fluorescence HLA_type  \
# 0        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 1        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 2        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 3        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 4        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# ..           ...            ...         ...                   ...      ...
# 799   HCV-K1Y17V              2  YLVALGVNAV                   APC   A02:01
# 800   HCV-K1Y17V              2  YLVALGVNAV                   APC   A02:01
# 801   HCV-K1Y17V              2  YLVALGVNAV                   APC   A02:01
# 802   HCV-K1Y17V              2  YLVALGVNAV                   APC   A02:01
# 803      PPI-RLL              2   RLLPLLALL                    PE   A02:01
#
#          TRAV       CDR3alpha
# 0    38-2/DV8  CAYRSPPSSEKLVF
# 1    38-2/DV8  CAYRSPPSSEKLVF
# 2    38-2/DV8  CAYRSPPSSEKLVF
# 3    38-2/DV8  CAYRSPPSSEKLVF
# 4    38-2/DV8  CAYRSPPSSEKLVF
# ..        ...             ...
# 799       NaN             NaN
# 800       NaN             NaN
# 801       NaN             NaN
# 802       NaN             NaN
# 803       NaN             NaN
#
# [804 rows x 12 columns]

# %% [markdown]
# Tutaj sprawdzamy w obrębie remaining_cols czy mamy jakieś duplikaty. Potem sprawdzamy czy gdzieś występuje NaN zestaw TRAV & CDR3alpha.

# %%
mask_remaining = Exp2_final.duplicated(subset=remaining_cols)
mask_melted = Exp2_final[['TRAV', 'CDR3alpha']].isna().all(axis=1)

mask_redundant = mask_remaining & mask_melted

Exp2_final = Exp2_final[~(mask_remaining & mask_melted).values]
Exp2_final
# Out:
#     cell_name sorted_population TRBV          CDR3beta peptide_rank  \
# 0        WA11             Clone   28   CASSFLGTGLNEQYF       rank_1
# 1        WB11             Clone   28   CASSFLGTGLNEQYF       rank_1
# 2        WC11             Clone   28   CASSFLGTGLNEQYF       rank_1
# 3        WE11             Clone   28   CASSFLGTGLNEQYF       rank_1
# 4        WF11             Clone   28   CASSFLGTGLNEQYF       rank_1
# ..        ...               ...  ...               ...          ...
# 613       UC6        Self_Naive  6-5  CASSYSQGVYTGELFF       rank_1
# 734       WB5        Self_Naive   19     CASSTTEAYEQYF       rank_1
# 745       WC6        Self_Naive    9  CASSALAGGQADTQYF       rank_1
# 764       TG1     Foreign_Naive  NaN               NaN       rank_2
# 773       WB5        Self_Naive   19     CASSTTEAYEQYF       rank_2
#
#     peptide_name  no_experiment peptide_seq tetramer_fluorescence HLA_type  \
# 0        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 1        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 2        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 3        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# 4        HCV-K1Y              2  YLVALGINAV                   APC   A02:01
# ..           ...            ...         ...                   ...      ...
# 613    MART1-A2L              2  ELAGIGILTV                    PE   A02:01
# 734    GP100-IMD              2   IMDQVPFSV                    PE   A02:01
# 745     ZNT8-LLS              2   LLSLFSLWL                    PE   A02:01
# 764     HAFP-FMN              2   FMNKFIYEI                    PE   A02:01
# 773    GP100-ITD              2   ITDQVPFSV                    PE   A02:01
#
#          TRAV            CDR3alpha
# 0    38-2/DV8       CAYRSPPSSEKLVF
# 1    38-2/DV8       CAYRSPPSSEKLVF
# 2    38-2/DV8       CAYRSPPSSEKLVF
# 3    38-2/DV8       CAYRSPPSSEKLVF
# 4    38-2/DV8       CAYRSPPSSEKLVF
# ..        ...                  ...
# 613        25             CAGYKLVF
# 734       8-3        CAGGPYNTDKLIF
# 745      26-1  CIVRVECMYSGGGADGLTF
# 764      12-2         CAVSNQGGKLIF
# 773       8-3        CAGGPYNTDKLIF
#
# [416 rows x 12 columns]

# %% [markdown]
# Interesują nas oryginały puste, oryginały pełne, oraz duplikaty pełne.

# %%
Exp2_final["TRAV"].unique()
# Out:
# array(['38-2/DV8', '12-2', nan, '12-1', '10', '39', '24', '14/DV4', '27',
#        '25', '29/DV5', '17', '8-3', '4', '8-2', '20', '19', '3', '26-2',
#        '35', '38-1', '12-3', '8-4', '9-2', '41', '16', '1-2', '8-1', '5',
#        '26-1'], dtype=object)

# %%
Exp2_final["TRBV"].unique()
# Out:
# array(['28', '10-3', '15', '6-1', '4-1', nan, '27', '20-1', '11-2', '9',
#        '13', '5-5', '19', '25-1', '3-1', '2', '6-5', '4-2', '6-2,6-3',
#        '5-1', '29-1', '10-2', '7-8', '7-2', '30', '12-3,12-4', '24-1',
#        '11-1', '4-3', '5-6', '14', '7-9', '6-4', '18', '5-4', '10-1',
#        '12-5', '6-6'], dtype=object)

# %% [markdown]
# Czyli tutaj brakuje końcówek *01

# %%
Exp2_final = Exp2_final.reset_index(drop=True)

# %%
Exp2_final.to_csv("../../../data/processed/zhang/Exp2_merged.csv.gz")

# %% [markdown]
# <b>ST5 - Experiment 3

# %%
ST5 = pd.read_excel("../../../data/original/zhang/ST5.xlsx")

# %%
new_columns = ["Cell Name", "Sorted Population", "rank_1", "rank_2", "rank_3", "rank_4", "rank_5" ,"TRAV1", "CDR3α,1", "TRAV2", "CDR3α,2", "TRBV", "CDR3β"]

# %%
ST5.columns = new_columns

# %%
ST5 = ST5.iloc[2:, :].reset_index(drop=True)

# %%
ST5
# Out:
#     Cell Name Sorted Population     rank_1       rank_2 rank_3 rank_4 rank_5  \
# 0         BA1           Neo+WT+      GANAB    GANAB-S5F      0      0      0
# 1        BA10           Neo+WT+    HCV-KLV            0      0      0      0
# 2        BA11           Neo+WT+  NSDHL-A9V        NSDHL      0      0      0
# 3         BA2           Neo+WT+    SMARCD3  SMARCD3-H8Y      0      0      0
# 4         BA3           Neo+WT+      USP28            0      0      0      0
# ..        ...               ...        ...          ...    ...    ...    ...
# 268       CC8           Neo-WT+     SEC24A            0      0      0      0
# 269       CD6           Neo-WT+      GANAB            0      0      0      0
# 270      CH11           Neo-WT+      GANAB            0      0      0      0
# 271       CH4           Neo-WT+     SEC24A            0      0      0      0
# 272       CH5           Neo-WT+      GANAB            0      0      0      0
#
#                TRAV1            CDR3α,1 TRAV2 CDR3α,2             TRBV  \
# 0                NaN                NaN   NaN     NaN          29-1*01
# 1                NaN                NaN   NaN     NaN           7-9*01
# 2          14/DV4*01    CAMRESNTGGFKTIF   NaN     NaN              NaN
# 3               5*01        CAVYNTDKLIF   NaN     NaN           4-1*01
# 4    13-2*01/13-2*02         GGTSYGKLTF   NaN     NaN  12-3*01,12-4*01
# ..               ...                ...   ...     ...              ...
# 268              NaN                NaN   NaN     NaN              NaN
# 269          12-2*01         CAVNNARLMF   NaN     NaN           4-3*01
# 270          12-2*01         CAVNNARLMF   NaN     NaN           4-3*01
# 271        14/DV4*01  CAMREFYSGGGADGLTF   NaN     NaN             2*01
# 272          12-2*01         CAVNNARLMF   NaN     NaN           4-3*01
#
#                  CDR3β
# 0        CSVPEGNTGELFF
# 1          CASSLEGEQYF
# 2                  NaN
# 3         CASSQGALGYTF
# 4    CASSFPDRGQGVYGYTF
# ..                 ...
# 268                NaN
# 269    CASSQGGGGTDTQYF
# 270    CASSQGGGGTDTQYF
# 271     CASSEDRGNSPLHF
# 272    CASSQGGGGTDTQYF
#
# [273 rows x 13 columns]

# %%
remaining_cols = [col for col in ST5.columns if col not in ["rank_1", "rank_2", "rank_3", "rank_4", "rank_5"]]
remaining_cols
# Out:
# ['Cell Name',
#  'Sorted Population',
#  'TRAV1',
#  'CDR3α,1',
#  'TRAV2',
#  'CDR3α,2',
#  'TRBV',
#  'CDR3β']

# %%
ST5 = ST5.melt(id_vars=remaining_cols, value_vars=["rank_1", "rank_2", "rank_3", "rank_4", "rank_5"], value_name='peptide_name')

# %%
ST5 = ST5.rename(columns={'variable':'peptide_rank'})

# %%
ST5.columns
# Out:
# Index(['Cell Name', 'Sorted Population', 'TRAV1', 'CDR3α,1', 'TRAV2',
#        'CDR3α,2', 'TRBV', 'CDR3β', 'peptide_rank', 'peptide_name'],
#       dtype='object')

# %%
ST5["no_experiment"] = "3"

# %%
ST5 = ST5.astype({"no_experiment": "int64"})

# %%
Exp3 = ST5.merge(ST1, on = ["peptide_name", "no_experiment"])

# %%
Exp3
# Out:
#     Cell Name Sorted Population      TRAV1         CDR3α,1 TRAV2 CDR3α,2  \
# 0         BA1           Neo+WT+        NaN             NaN   NaN     NaN
# 1         BA4           Neo-WT+    12-2*01      CAVNNARLMF   NaN     NaN
# 2         BA7           Neo-WT+    12-2*01      CAIEGGKLIF   NaN     NaN
# 3         BB2           Neo-WT+    12-2*01      CAVNNARLMF   NaN     NaN
# 4         BB3           Neo-WT+    12-3*01   CAMKDFGNEKLTF   NaN     NaN
# ..        ...               ...        ...             ...   ...     ...
# 97       BB11           Neo+WT+      25*01   CAGRKTSYDKVIF   NaN     NaN
# 98        BG4           Neo-WT+  23/DV6*01  CAASLNTNAGKSTF   NaN     NaN
# 99        BH3           Neo-WT+    13-2*01    CAENKDDYKLSF   NaN     NaN
# 100       CH6           Neo+WT+    12-1*01  CVVSPYNQGGKLIF   NaN     NaN
# 101       CH6           Neo+WT+    12-1*01  CVVSPYNQGGKLIF   NaN     NaN
#
#         TRBV              CDR3β peptide_rank peptide_name  no_experiment  \
# 0    29-1*01      CSVPEGNTGELFF       rank_1        GANAB              3
# 1     4-3*01    CASSQGGGGTDTQYF       rank_1        GANAB              3
# 2       2*01      CASSDWGGETQYF       rank_1        GANAB              3
# 3     4-3*01    CASSQGGGGTDTQYF       rank_1        GANAB              3
# 4       2*01        CSWDFQETQYF       rank_1        GANAB              3
# ..       ...                ...          ...          ...            ...
# 97    4-3*01  CASSYASTGTLNYGYTF       rank_2       SEC24A              3
# 98     30*01       CAWSVGNYGYTF       rank_1      COL18A1              3
# 99    7-8*01      CASSFSATGELFF       rank_1        SNX24              3
# 100   7-9*01     CASSLDIGDQPQHF       rank_2        GNL3L              3
# 101   7-9*01     CASSLDIGDQPQHF       rank_3       PABPC1              3
#
#     peptide_seq tetramer_fluorescence HLA_type
# 0     ALYGSVPVL                    PE   A02:01
# 1     ALYGSVPVL                    PE   A02:01
# 2     ALYGSVPVL                    PE   A02:01
# 3     ALYGSVPVL                    PE   A02:01
# 4     ALYGSVPVL                    PE   A02:01
# ..          ...                   ...      ...
# 97    FLYNPLTRV                    PE   A02:01
# 98   VLLGVKLSGV                    PE   A02:01
# 99    KLSHQPVLL                    PE   A02:01
# 100   NLNRCSVPV                    PE   A02:01
# 101   MLGERLFPL                    PE   A02:01
#
# [102 rows x 14 columns]

# %%
Exp3 = Exp3.rename(columns={"Cell Name": "cell_name", "Sorted Population": "sorted_population", "CDR3α,1": "CDR3alpha_1", "CDR3α,2":"CDR3alpha_2", "CDR3β": "CDR3beta"})

# %% [markdown]
# Mam dwa warianty łańcucha TRAV -> chce zrobić z tego wiersze

# %%
remaining_cols = [col for col in Exp3.columns if col not in ['TRAV1', 'TRAV2', 'CDR3alpha_1', 'CDR3alpha_2']]
remaining_cols
# Out:
# ['cell_name',
#  'sorted_population',
#  'TRBV',
#  'CDR3beta',
#  'peptide_rank',
#  'peptide_name',
#  'no_experiment',
#  'peptide_seq',
#  'tetramer_fluorescence',
#  'HLA_type']

# %%
Exp3.cell_name.duplicated().sum()
# Out:
# 3

# %%
Exp3_trav = Exp3.melt(id_vars=remaining_cols, value_vars=['TRAV1', 'TRAV2'], value_name='TRAV')
Exp3_trav
# Out:
#     cell_name sorted_population     TRBV           CDR3beta peptide_rank  \
# 0         BA1           Neo+WT+  29-1*01      CSVPEGNTGELFF       rank_1
# 1         BA4           Neo-WT+   4-3*01    CASSQGGGGTDTQYF       rank_1
# 2         BA7           Neo-WT+     2*01      CASSDWGGETQYF       rank_1
# 3         BB2           Neo-WT+   4-3*01    CASSQGGGGTDTQYF       rank_1
# 4         BB3           Neo-WT+     2*01        CSWDFQETQYF       rank_1
# ..        ...               ...      ...                ...          ...
# 199      BB11           Neo+WT+   4-3*01  CASSYASTGTLNYGYTF       rank_2
# 200       BG4           Neo-WT+    30*01       CAWSVGNYGYTF       rank_1
# 201       BH3           Neo-WT+   7-8*01      CASSFSATGELFF       rank_1
# 202       CH6           Neo+WT+   7-9*01     CASSLDIGDQPQHF       rank_2
# 203       CH6           Neo+WT+   7-9*01     CASSLDIGDQPQHF       rank_3
#
#     peptide_name  no_experiment peptide_seq tetramer_fluorescence HLA_type  \
# 0          GANAB              3   ALYGSVPVL                    PE   A02:01
# 1          GANAB              3   ALYGSVPVL                    PE   A02:01
# 2          GANAB              3   ALYGSVPVL                    PE   A02:01
# 3          GANAB              3   ALYGSVPVL                    PE   A02:01
# 4          GANAB              3   ALYGSVPVL                    PE   A02:01
# ..           ...            ...         ...                   ...      ...
# 199       SEC24A              3   FLYNPLTRV                    PE   A02:01
# 200      COL18A1              3  VLLGVKLSGV                    PE   A02:01
# 201        SNX24              3   KLSHQPVLL                    PE   A02:01
# 202        GNL3L              3   NLNRCSVPV                    PE   A02:01
# 203       PABPC1              3   MLGERLFPL                    PE   A02:01
#
#     variable     TRAV
# 0      TRAV1      NaN
# 1      TRAV1  12-2*01
# 2      TRAV1  12-2*01
# 3      TRAV1  12-2*01
# 4      TRAV1  12-3*01
# ..       ...      ...
# 199    TRAV2      NaN
# 200    TRAV2      NaN
# 201    TRAV2      NaN
# 202    TRAV2      NaN
# 203    TRAV2      NaN
#
# [204 rows x 12 columns]

# %%
Exp3_cdr3alpha = Exp3.melt(id_vars=remaining_cols, value_vars=['CDR3alpha_1', 'CDR3alpha_2'], value_name='CDR3alpha')
Exp3_cdr3alpha
# Out:
#     cell_name sorted_population     TRBV           CDR3beta peptide_rank  \
# 0         BA1           Neo+WT+  29-1*01      CSVPEGNTGELFF       rank_1
# 1         BA4           Neo-WT+   4-3*01    CASSQGGGGTDTQYF       rank_1
# 2         BA7           Neo-WT+     2*01      CASSDWGGETQYF       rank_1
# 3         BB2           Neo-WT+   4-3*01    CASSQGGGGTDTQYF       rank_1
# 4         BB3           Neo-WT+     2*01        CSWDFQETQYF       rank_1
# ..        ...               ...      ...                ...          ...
# 199      BB11           Neo+WT+   4-3*01  CASSYASTGTLNYGYTF       rank_2
# 200       BG4           Neo-WT+    30*01       CAWSVGNYGYTF       rank_1
# 201       BH3           Neo-WT+   7-8*01      CASSFSATGELFF       rank_1
# 202       CH6           Neo+WT+   7-9*01     CASSLDIGDQPQHF       rank_2
# 203       CH6           Neo+WT+   7-9*01     CASSLDIGDQPQHF       rank_3
#
#     peptide_name  no_experiment peptide_seq tetramer_fluorescence HLA_type  \
# 0          GANAB              3   ALYGSVPVL                    PE   A02:01
# 1          GANAB              3   ALYGSVPVL                    PE   A02:01
# 2          GANAB              3   ALYGSVPVL                    PE   A02:01
# 3          GANAB              3   ALYGSVPVL                    PE   A02:01
# 4          GANAB              3   ALYGSVPVL                    PE   A02:01
# ..           ...            ...         ...                   ...      ...
# 199       SEC24A              3   FLYNPLTRV                    PE   A02:01
# 200      COL18A1              3  VLLGVKLSGV                    PE   A02:01
# 201        SNX24              3   KLSHQPVLL                    PE   A02:01
# 202        GNL3L              3   NLNRCSVPV                    PE   A02:01
# 203       PABPC1              3   MLGERLFPL                    PE   A02:01
#
#         variable      CDR3alpha
# 0    CDR3alpha_1            NaN
# 1    CDR3alpha_1     CAVNNARLMF
# 2    CDR3alpha_1     CAIEGGKLIF
# 3    CDR3alpha_1     CAVNNARLMF
# 4    CDR3alpha_1  CAMKDFGNEKLTF
# ..           ...            ...
# 199  CDR3alpha_2            NaN
# 200  CDR3alpha_2            NaN
# 201  CDR3alpha_2            NaN
# 202  CDR3alpha_2            NaN
# 203  CDR3alpha_2            NaN
#
# [204 rows x 12 columns]

# %%
Exp3_trav.drop(columns=['variable'], inplace=True)
Exp3_cdr3alpha.drop(columns=['variable'], inplace=True)

# %%
assert (Exp3_trav.cell_name == Exp3_cdr3alpha.cell_name).all()

# %%
Exp3_final = pd.concat([Exp3_trav,Exp3_cdr3alpha['CDR3alpha']], axis=1)
Exp3_final
# Out:
#     cell_name sorted_population     TRBV           CDR3beta peptide_rank  \
# 0         BA1           Neo+WT+  29-1*01      CSVPEGNTGELFF       rank_1
# 1         BA4           Neo-WT+   4-3*01    CASSQGGGGTDTQYF       rank_1
# 2         BA7           Neo-WT+     2*01      CASSDWGGETQYF       rank_1
# 3         BB2           Neo-WT+   4-3*01    CASSQGGGGTDTQYF       rank_1
# 4         BB3           Neo-WT+     2*01        CSWDFQETQYF       rank_1
# ..        ...               ...      ...                ...          ...
# 199      BB11           Neo+WT+   4-3*01  CASSYASTGTLNYGYTF       rank_2
# 200       BG4           Neo-WT+    30*01       CAWSVGNYGYTF       rank_1
# 201       BH3           Neo-WT+   7-8*01      CASSFSATGELFF       rank_1
# 202       CH6           Neo+WT+   7-9*01     CASSLDIGDQPQHF       rank_2
# 203       CH6           Neo+WT+   7-9*01     CASSLDIGDQPQHF       rank_3
#
#     peptide_name  no_experiment peptide_seq tetramer_fluorescence HLA_type  \
# 0          GANAB              3   ALYGSVPVL                    PE   A02:01
# 1          GANAB              3   ALYGSVPVL                    PE   A02:01
# 2          GANAB              3   ALYGSVPVL                    PE   A02:01
# 3          GANAB              3   ALYGSVPVL                    PE   A02:01
# 4          GANAB              3   ALYGSVPVL                    PE   A02:01
# ..           ...            ...         ...                   ...      ...
# 199       SEC24A              3   FLYNPLTRV                    PE   A02:01
# 200      COL18A1              3  VLLGVKLSGV                    PE   A02:01
# 201        SNX24              3   KLSHQPVLL                    PE   A02:01
# 202        GNL3L              3   NLNRCSVPV                    PE   A02:01
# 203       PABPC1              3   MLGERLFPL                    PE   A02:01
#
#         TRAV      CDR3alpha
# 0        NaN            NaN
# 1    12-2*01     CAVNNARLMF
# 2    12-2*01     CAIEGGKLIF
# 3    12-2*01     CAVNNARLMF
# 4    12-3*01  CAMKDFGNEKLTF
# ..       ...            ...
# 199      NaN            NaN
# 200      NaN            NaN
# 201      NaN            NaN
# 202      NaN            NaN
# 203      NaN            NaN
#
# [204 rows x 12 columns]

# %% [markdown]
# Tutaj sprawdzamy w obrębie remaining_cols czy mamy jakieś duplikaty. Potem sprawdzamy czy gdzieś występuje NaN zestaw TRAV & CDR3alpha.

# %%
mask_remaining = Exp3_final.duplicated(subset=remaining_cols)
mask_melted = Exp3_final[['TRAV', 'CDR3alpha']].isna().all(axis=1)

mask_redundant = mask_remaining & mask_melted

Exp3_final = Exp3_final[~(mask_remaining & mask_melted).values]
Exp3_final
# Out:
#     cell_name sorted_population             TRBV         CDR3beta  \
# 0         BA1           Neo+WT+          29-1*01    CSVPEGNTGELFF
# 1         BA4           Neo-WT+           4-3*01  CASSQGGGGTDTQYF
# 2         BA7           Neo-WT+             2*01    CASSDWGGETQYF
# 3         BB2           Neo-WT+           4-3*01  CASSQGGGGTDTQYF
# 4         BB3           Neo-WT+             2*01      CSWDFQETQYF
# ..        ...               ...              ...              ...
# 156       BC6           Neo-WT+             9*01  CASSVETGGLDTQYF
# 168       CC6           Neo+WT+             9*01  CASSVETGGLDTQYF
# 180       BG1           Neo+WT+  12-3*01,12-4*01     CASSPDPYEQYF
# 185       CB9           Neo-WT+           3-1*01      CASSLAYEQYF
# 194       BF4           Neo-WT+           7-2*01    CASSLREAGELFF
#
#     peptide_rank peptide_name  no_experiment peptide_seq  \
# 0         rank_1        GANAB              3   ALYGSVPVL
# 1         rank_1        GANAB              3   ALYGSVPVL
# 2         rank_1        GANAB              3   ALYGSVPVL
# 3         rank_1        GANAB              3   ALYGSVPVL
# 4         rank_1        GANAB              3   ALYGSVPVL
# ..           ...          ...            ...         ...
# 156       rank_1       FNDC3B              3   VVLSWAPPV
# 168       rank_2         MLL2              3   ALSPVIPLI
# 180       rank_1         MRM1              3   LLFGMTPCL
# 185       rank_1         PGM5              3   AVGSHVYSV
# 194       rank_1       SEC24A              3   FLYNPLTRV
#
#     tetramer_fluorescence HLA_type     TRAV        CDR3alpha
# 0                      PE   A02:01      NaN              NaN
# 1                      PE   A02:01  12-2*01       CAVNNARLMF
# 2                      PE   A02:01  12-2*01       CAIEGGKLIF
# 3                      PE   A02:01  12-2*01       CAVNNARLMF
# 4                      PE   A02:01  12-3*01    CAMKDFGNEKLTF
# ..                    ...      ...      ...              ...
# 156                    PE   A02:01  12-1*01   CVVISTDSWGKFQF
# 168                    PE   A02:01    17*01  CATASLRNYGQNFVF
# 180                    PE   A02:01  13-2*01    CAVVMEYGNKLVF
# 185                    PE   A02:01   9-2*01   CAPPIEGGSEKLVF
# 194                    PE   A02:01    17*01     CATDVYDYKLSF
#
# [107 rows x 12 columns]

# %% [markdown]
# Interesują nas oryginały puste, oryginały pełne, oraz duplikaty pełne.

# %%
Exp3_final["TRAV"].unique()
# Out:
# array([nan, '12-2*01', '12-3*01', '5*01', '8-1*01', '13-2*01/13-2*02',
#        '8-3*01', '38-2/DV8*01', '9-2*01', '14/DV4*01', '38-1*01', '19*01',
#        '3*01', '29/DV5*01', '17*01', '41*01 F', '1-2*01', '24*01',
#        '21*01', '10*01', '8-4*01', '41*01', '35*01', '12-1*01', '22*01',
#        '22*01 F', '25*01', '23/DV6*01', '13-2*01'], dtype=object)

# %%
Exp3_final["TRBV"].unique()
# Out:
# array(['29-1*01', '4-3*01', '2*01', nan, '6-2*01,6-3*01', '4-1*01',
#        '27*01', '12-3*01,12-4*01', '7-2*01', '20-1*01', '7-9*01',
#        '5-4*01', '6-6*01', '15*01', '9*01', '7-8*01', '10-3*01', '13*01',
#        '6-5*01', '28*01', '19*01', '7-7*01', '5-8*01', '5-5*01', '6-1*01',
#        '7-6*01', '4-2*01', '25-1*01', '3-1*01', '18*01', '11-2*01',
#        '5-6*01', '30*01'], dtype=object)

# %%
Exp3_final = Exp3_final.reset_index(drop=True)

# %%
Exp3_final.to_csv("../../../data/processed/zhang/Exp3_merged.csv.gz")

# %% [markdown]
# <b>ST6 - Experiment 4

# %%
ST6 = pd.read_excel("../../../data/original/zhang/ST6.xlsx")

# %%
new_columns = ["Cell Name", "Sorted Population", "rank_1", "rank_2", "rank_3", "rank_4", "rank_5","TRAV1", "CDR3α,1", "TRAV2", "CDR3α,2", "TRBV", "CDR3β"]

# %%
ST6.columns = new_columns

# %%
ST6 = ST6.iloc[2:, :].reset_index(drop=True)

# %%
ST6
# Out:
#     Cell Name Sorted Population       rank_1 rank_2 rank_3 rank_4 rank_5  \
# 0         G23           Neo+WT+            0      0      0      0      0
# 1          G6           Neo+WT+            0      0      0      0      0
# 2         H10           Neo+WT+            0      0      0      0      0
# 3          H9           Neo+WT+            0      0      0      0      0
# 4         I12           Neo+WT+            0      0      0      0      0
# ..        ...               ...          ...    ...    ...    ...    ...
# 291       K18           Neo-WT+        SNX24      0      0      0      0
# 292       H18           Neo-WT+  TEAD1_(VLE)      0      0      0      0
# 293        J3           Neo-WT+        USP28      0      0      0      0
# 294       H13           Neo-WT+        WDR46      0      0      0      0
# 295       J22           Neo-WT+        WDR46      0      0      0      0
#
#        TRAV1        CDR3α,1 TRAV2 CDR3α,2           TRBV             CDR3β
# 0        NaN            NaN   NaN     NaN            NaN               NaN
# 1        NaN            NaN   NaN     NaN          15*01      CATSQMGDTQYF
# 2       3*01  CAVGFYGNNRLAF   NaN     NaN            NaN               NaN
# 3        NaN            NaN   NaN     NaN  6-2*01,6-3*01  CASSPFGDMLYNEQFF
# 4    12-2*01     CAVRNNDMRF   NaN     NaN            NaN               NaN
# ..       ...            ...   ...     ...            ...               ...
# 291      NaN            NaN   NaN     NaN            NaN               NaN
# 292    24*01   CAFSQYGNKLVF   NaN     NaN            NaN               NaN
# 293      NaN            NaN   NaN     NaN            NaN               NaN
# 294      NaN            NaN   NaN     NaN            NaN               NaN
# 295      NaN            NaN   NaN     NaN            NaN               NaN
#
# [296 rows x 13 columns]

# %%
remaining_cols = [col for col in ST6.columns if col not in ["rank_1", "rank_2", "rank_3", "rank_4", "rank_5"]]
remaining_cols
# Out:
# ['Cell Name',
#  'Sorted Population',
#  'TRAV1',
#  'CDR3α,1',
#  'TRAV2',
#  'CDR3α,2',
#  'TRBV',
#  'CDR3β']

# %%
ST6 = ST6.melt(id_vars=remaining_cols, value_vars=["rank_1", "rank_2", "rank_3", "rank_4", "rank_5"], value_name='peptide_name')

# %%
ST6 = ST6.rename(columns={'variable':'peptide_rank'})

# %%
ST6.columns
# Out:
# Index(['Cell Name', 'Sorted Population', 'TRAV1', 'CDR3α,1', 'TRAV2',
#        'CDR3α,2', 'TRBV', 'CDR3β', 'peptide_rank', 'peptide_name'],
#       dtype='object')

# %%
ST6["no_experiment"] = "4"

# %%
ST6 = ST6.astype({"no_experiment": "int64"})

# %%
Exp4 = ST6.merge(ST1, on = ["peptide_name", "no_experiment"])

# %%
Exp4
# Out:
#     Cell Name Sorted Population        TRAV1    CDR3α,1 TRAV2 CDR3α,2  \
# 0         H23           Neo+WT+          NaN        NaN   NaN     NaN
# 1          H4           Neo+WT+          NaN        NaN   NaN     NaN
# 2          K2           Neo+WT+          NaN        NaN   NaN     NaN
# 3          G5           Neo-WT+          NaN        NaN   NaN     NaN
# 4         H21           Neo-WT+  38-2/DV8*01  CAYSPPLVF   NaN     NaN
# ..        ...               ...          ...        ...   ...     ...
# 138       J22           Neo-WT+          NaN        NaN   NaN     NaN
# 139       K14           Neo-WT+          NaN        NaN   NaN     NaN
# 140        J3           Neo-WT+          NaN        NaN   NaN     NaN
# 141       G20           Neo+WT+          NaN        NaN   NaN     NaN
# 142        H5           Neo+WT+          NaN        NaN   NaN     NaN
#
#               TRBV           CDR3β peptide_rank  peptide_name  no_experiment  \
# 0              NaN             NaN       rank_1        AKAP13              4
# 1              NaN             NaN       rank_1        AKAP13              4
# 2          29-1*01  CSVEGLRGGNEQFF       rank_1        AKAP13              4
# 3              NaN             NaN       rank_1        AKAP13              4
# 4    6-2*01,6-3*01   CASRGGDGETQYF       rank_1        AKAP13              4
# ..             ...             ...          ...           ...            ...
# 138            NaN             NaN       rank_1         WDR46              4
# 139          19*01    CATWDSGNIQYF       rank_1   MAGEA3_KVAE              4
# 140            NaN             NaN       rank_1         USP28              4
# 141            NaN             NaN       rank_4         USP28              4
# 142            NaN             NaN       rank_2  MAGEA12_KMAE              4
#
#     peptide_seq tetramer_fluorescence HLA_type
# 0     KLMNIQQQL                    PE   A02:01
# 1     KLMNIQQQL                    PE   A02:01
# 2     KLMNIQQQL                    PE   A02:01
# 3     KLMNIQQQL                    PE   A02:01
# 4     KLMNIQQQL                    PE   A02:01
# ..          ...                   ...      ...
# 138   FLTYLDVSV                    PE   A02:01
# 139   KVAELVHFL                    PE   A02:01
# 140   LIIPCIHLI                    PE   A02:01
# 141   LIIPCIHLI                    PE   A02:01
# 142   KMAELVHFL                   APC   A02:01
#
# [143 rows x 14 columns]

# %%
Exp4 = Exp4.rename(columns={"Cell Name": "cell_name", "Sorted Population": "sorted_population", "CDR3α,1": "CDR3alpha_1", "CDR3α,2":"CDR3alpha_2", "CDR3β": "CDR3beta"})

# %% [markdown]
# Mam dwa warianty łańcucha TRAV -> chce zrobić z tego wiersze

# %%
remaining_cols = [col for col in Exp4.columns if col not in ['TRAV1', 'TRAV2', 'CDR3alpha_1', 'CDR3alpha_2']]
remaining_cols
# Out:
# ['cell_name',
#  'sorted_population',
#  'TRBV',
#  'CDR3beta',
#  'peptide_rank',
#  'peptide_name',
#  'no_experiment',
#  'peptide_seq',
#  'tetramer_fluorescence',
#  'HLA_type']

# %%
Exp4.cell_name.duplicated().sum()
# Out:
# 6

# %%
Exp4_trav = Exp4.melt(id_vars=remaining_cols, value_vars=['TRAV1', 'TRAV2'], value_name='TRAV')
Exp4_trav
# Out:
#     cell_name sorted_population           TRBV        CDR3beta peptide_rank  \
# 0         H23           Neo+WT+            NaN             NaN       rank_1
# 1          H4           Neo+WT+            NaN             NaN       rank_1
# 2          K2           Neo+WT+        29-1*01  CSVEGLRGGNEQFF       rank_1
# 3          G5           Neo-WT+            NaN             NaN       rank_1
# 4         H21           Neo-WT+  6-2*01,6-3*01   CASRGGDGETQYF       rank_1
# ..        ...               ...            ...             ...          ...
# 281       J22           Neo-WT+            NaN             NaN       rank_1
# 282       K14           Neo-WT+          19*01    CATWDSGNIQYF       rank_1
# 283        J3           Neo-WT+            NaN             NaN       rank_1
# 284       G20           Neo+WT+            NaN             NaN       rank_4
# 285        H5           Neo+WT+            NaN             NaN       rank_2
#
#      peptide_name  no_experiment peptide_seq tetramer_fluorescence HLA_type  \
# 0          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 1          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 2          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 3          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 4          AKAP13              4   KLMNIQQQL                    PE   A02:01
# ..            ...            ...         ...                   ...      ...
# 281         WDR46              4   FLTYLDVSV                    PE   A02:01
# 282   MAGEA3_KVAE              4   KVAELVHFL                    PE   A02:01
# 283         USP28              4   LIIPCIHLI                    PE   A02:01
# 284         USP28              4   LIIPCIHLI                    PE   A02:01
# 285  MAGEA12_KMAE              4   KMAELVHFL                   APC   A02:01
#
#     variable         TRAV
# 0      TRAV1          NaN
# 1      TRAV1          NaN
# 2      TRAV1          NaN
# 3      TRAV1          NaN
# 4      TRAV1  38-2/DV8*01
# ..       ...          ...
# 281    TRAV2          NaN
# 282    TRAV2          NaN
# 283    TRAV2          NaN
# 284    TRAV2          NaN
# 285    TRAV2          NaN
#
# [286 rows x 12 columns]

# %%
Exp4_cdr3alpha = Exp4.melt(id_vars=remaining_cols, value_vars=['CDR3alpha_1', 'CDR3alpha_2'], value_name='CDR3alpha')
Exp4_cdr3alpha
# Out:
#     cell_name sorted_population           TRBV        CDR3beta peptide_rank  \
# 0         H23           Neo+WT+            NaN             NaN       rank_1
# 1          H4           Neo+WT+            NaN             NaN       rank_1
# 2          K2           Neo+WT+        29-1*01  CSVEGLRGGNEQFF       rank_1
# 3          G5           Neo-WT+            NaN             NaN       rank_1
# 4         H21           Neo-WT+  6-2*01,6-3*01   CASRGGDGETQYF       rank_1
# ..        ...               ...            ...             ...          ...
# 281       J22           Neo-WT+            NaN             NaN       rank_1
# 282       K14           Neo-WT+          19*01    CATWDSGNIQYF       rank_1
# 283        J3           Neo-WT+            NaN             NaN       rank_1
# 284       G20           Neo+WT+            NaN             NaN       rank_4
# 285        H5           Neo+WT+            NaN             NaN       rank_2
#
#      peptide_name  no_experiment peptide_seq tetramer_fluorescence HLA_type  \
# 0          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 1          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 2          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 3          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 4          AKAP13              4   KLMNIQQQL                    PE   A02:01
# ..            ...            ...         ...                   ...      ...
# 281         WDR46              4   FLTYLDVSV                    PE   A02:01
# 282   MAGEA3_KVAE              4   KVAELVHFL                    PE   A02:01
# 283         USP28              4   LIIPCIHLI                    PE   A02:01
# 284         USP28              4   LIIPCIHLI                    PE   A02:01
# 285  MAGEA12_KMAE              4   KMAELVHFL                   APC   A02:01
#
#         variable  CDR3alpha
# 0    CDR3alpha_1        NaN
# 1    CDR3alpha_1        NaN
# 2    CDR3alpha_1        NaN
# 3    CDR3alpha_1        NaN
# 4    CDR3alpha_1  CAYSPPLVF
# ..           ...        ...
# 281  CDR3alpha_2        NaN
# 282  CDR3alpha_2        NaN
# 283  CDR3alpha_2        NaN
# 284  CDR3alpha_2        NaN
# 285  CDR3alpha_2        NaN
#
# [286 rows x 12 columns]

# %%
Exp4_trav.drop(columns=['variable'], inplace=True)
Exp4_cdr3alpha.drop(columns=['variable'], inplace=True)

# %%
assert (Exp4_trav.cell_name == Exp4_cdr3alpha.cell_name).all()

# %%
Exp4_final = pd.concat([Exp4_trav,Exp4_cdr3alpha['CDR3alpha']], axis=1)
Exp4_final
# Out:
#     cell_name sorted_population           TRBV        CDR3beta peptide_rank  \
# 0         H23           Neo+WT+            NaN             NaN       rank_1
# 1          H4           Neo+WT+            NaN             NaN       rank_1
# 2          K2           Neo+WT+        29-1*01  CSVEGLRGGNEQFF       rank_1
# 3          G5           Neo-WT+            NaN             NaN       rank_1
# 4         H21           Neo-WT+  6-2*01,6-3*01   CASRGGDGETQYF       rank_1
# ..        ...               ...            ...             ...          ...
# 281       J22           Neo-WT+            NaN             NaN       rank_1
# 282       K14           Neo-WT+          19*01    CATWDSGNIQYF       rank_1
# 283        J3           Neo-WT+            NaN             NaN       rank_1
# 284       G20           Neo+WT+            NaN             NaN       rank_4
# 285        H5           Neo+WT+            NaN             NaN       rank_2
#
#      peptide_name  no_experiment peptide_seq tetramer_fluorescence HLA_type  \
# 0          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 1          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 2          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 3          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 4          AKAP13              4   KLMNIQQQL                    PE   A02:01
# ..            ...            ...         ...                   ...      ...
# 281         WDR46              4   FLTYLDVSV                    PE   A02:01
# 282   MAGEA3_KVAE              4   KVAELVHFL                    PE   A02:01
# 283         USP28              4   LIIPCIHLI                    PE   A02:01
# 284         USP28              4   LIIPCIHLI                    PE   A02:01
# 285  MAGEA12_KMAE              4   KMAELVHFL                   APC   A02:01
#
#             TRAV  CDR3alpha
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4    38-2/DV8*01  CAYSPPLVF
# ..           ...        ...
# 281          NaN        NaN
# 282          NaN        NaN
# 283          NaN        NaN
# 284          NaN        NaN
# 285          NaN        NaN
#
# [286 rows x 12 columns]

# %% [markdown]
# Tutaj sprawdzamy w obrębie remaining_cols czy mamy jakieś duplikaty. Potem sprawdzamy czy gdzieś występuje NaN zestaw TRAV & CDR3alpha.

# %%
mask_remaining = Exp4_final.duplicated(subset=remaining_cols)
mask_melted = Exp4_final[['TRAV', 'CDR3alpha']].isna().all(axis=1)

mask_redundant = mask_remaining & mask_melted

Exp4_final = Exp4_final[~(mask_remaining & mask_melted).values]
Exp4_final
# Out:
#     cell_name sorted_population           TRBV        CDR3beta peptide_rank  \
# 0         H23           Neo+WT+            NaN             NaN       rank_1
# 1          H4           Neo+WT+            NaN             NaN       rank_1
# 2          K2           Neo+WT+        29-1*01  CSVEGLRGGNEQFF       rank_1
# 3          G5           Neo-WT+            NaN             NaN       rank_1
# 4         H21           Neo-WT+  6-2*01,6-3*01   CASRGGDGETQYF       rank_1
# ..        ...               ...            ...             ...          ...
# 139       K14           Neo-WT+          19*01    CATWDSGNIQYF       rank_1
# 140        J3           Neo-WT+            NaN             NaN       rank_1
# 141       G20           Neo+WT+            NaN             NaN       rank_4
# 142        H5           Neo+WT+            NaN             NaN       rank_2
# 263        G8           Neo-WT+            NaN             NaN       rank_1
#
#      peptide_name  no_experiment peptide_seq tetramer_fluorescence HLA_type  \
# 0          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 1          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 2          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 3          AKAP13              4   KLMNIQQQL                    PE   A02:01
# 4          AKAP13              4   KLMNIQQQL                    PE   A02:01
# ..            ...            ...         ...                   ...      ...
# 139   MAGEA3_KVAE              4   KVAELVHFL                    PE   A02:01
# 140         USP28              4   LIIPCIHLI                    PE   A02:01
# 141         USP28              4   LIIPCIHLI                    PE   A02:01
# 142  MAGEA12_KMAE              4   KMAELVHFL                   APC   A02:01
# 263          PGM5              4   AVGSHVYSV                    PE   A02:01
#
#             TRAV        CDR3alpha
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4    38-2/DV8*01        CAYSPPLVF
# ..           ...              ...
# 139          NaN              NaN
# 140          NaN              NaN
# 141          NaN              NaN
# 142          NaN              NaN
# 263        19*01  CALTTDSNSGYALNF
#
# [144 rows x 12 columns]

# %% [markdown]
# Interesują nas oryginały puste, oryginały pełne, oraz duplikaty pełne.

# %%
Exp4_final["TRAV"].unique()
# Out:
# array([nan, '38-2/DV8*01', '38-1*01', '16*01', '14/DV4*01', '19*01',
#        '12-2*01', '29/DV5*01', '12-1*01', '5*01', '13-2*01', '12-3*01',
#        '3*01', '9-2*01', '1-2*01', '10*01', '24*01', '17*01', '35*01',
#        '22*01', '8-3*01'], dtype=object)

# %%
Exp4_final["TRBV"].unique()
# Out:
# array([nan, '29-1*01', '6-2*01,6-3*01', '9*01', '19*01', '13*01', '30*01',
#        '6-5*01', '5-4*01', '20-1*01', '3-1*01', '4-2*01', '4-3*01',
#        '7-9*01', '4-1*01', '12-3*01,12-4*01', '28*01', '27*01'],
#       dtype=object)

# %%
Exp4_final = Exp4_final.reset_index(drop=True)

# %%
Exp4_final.to_csv("../../../data/processed/zhang/Exp4_merged.csv.gz")

# %% [markdown]
# <b>ST8 - Experiment 5

# %%
ST8 = pd.read_excel("../../../data/original/zhang/ST8.xlsx")

# %%
new_columns = ["Cell Name", "Sorted Population", "rank_1", "rank_2", "rank_3", "rank_4", "rank_5","TRAV1", "CDR3α,1", "TRAV2", "CDR3α,2", "TRBV1", "CDR3β,1", "TRBV2", "CDR3β,2"]

# %%
ST8.columns = new_columns

# %%
ST8 = ST8.iloc[2:, :].reset_index(drop=True)

# %%
ST8
# Out:
#     Cell Name Sorted Population        rank_1        rank_2 rank_3 rank_4  \
# 0         SA1             Clone   HCV-KLV(PE)  HCV-KLV(APC)      0      0
# 1         SB1             Clone  HCV-KLV(APC)   HCV-KLV(PE)      0      0
# 2         SC1             Clone  HCV-KLV(APC)   HCV-KLV(PE)      0      0
# 3         SD1             Clone             0             0      0      0
# 4         SE1             Clone  HCV-KLV(APC)   HCV-KLV(PE)      0      0
# ..        ...               ...           ...           ...    ...    ...
# 791      SH10           Neo-WT+             0             0      0      0
# 792      SH11           Neo-WT+             0             0      0      0
# 793       SH3           Neo-WT+             0             0      0      0
# 794       SH5           Neo-WT+     ITIH6-RLG             0      0      0
# 795       SH7           Neo-WT+     ITIH6-RLG             0      0      0
#
#     rank_5        TRAV1         CDR3α,1 TRAV2 CDR3α,2   TRBV1  \
# 0        0  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN   28*01
# 1        0  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN   28*01
# 2        0  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN   28*01
# 3        0          NaN             NaN   NaN     NaN     NaN
# 4        0  38-2/DV8*01  CAYRSPPSSEKLVF   NaN     NaN   28*01
# ..     ...          ...             ...   ...     ...     ...
# 791      0          NaN             NaN   NaN     NaN     NaN
# 792      0          NaN             NaN   NaN     NaN     NaN
# 793      0          NaN             NaN   NaN     NaN     NaN
# 794      0        19*01      CALSEDQFYF   NaN     NaN  6-1*01
# 795      0          NaN             NaN   NaN     NaN     NaN
#
#              CDR3β,1 TRBV2 CDR3β,2
# 0    CASSFLGTGLNEQYF   NaN     NaN
# 1    CASSFLGTGLNEQYF   NaN     NaN
# 2    CASSFLGTGLNEQYF   NaN     NaN
# 3                NaN   NaN     NaN
# 4    CASSFLGTGLNEQYF   NaN     NaN
# ..               ...   ...     ...
# 791              NaN   NaN     NaN
# 792              NaN   NaN     NaN
# 793              NaN   NaN     NaN
# 794  CASRPGGGSYNEQFF   NaN     NaN
# 795              NaN   NaN     NaN
#
# [796 rows x 15 columns]

# %%
remaining_cols = [col for col in ST8.columns if col not in ["rank_1", "rank_2", "rank_3", "rank_4", "rank_5"]]
remaining_cols
# Out:
# ['Cell Name',
#  'Sorted Population',
#  'TRAV1',
#  'CDR3α,1',
#  'TRAV2',
#  'CDR3α,2',
#  'TRBV1',
#  'CDR3β,1',
#  'TRBV2',
#  'CDR3β,2']

# %%
ST8 = ST8.melt(id_vars=remaining_cols, value_vars=["rank_1", "rank_2", "rank_3", "rank_4", "rank_5"], value_name='peptide_name')

# %%
ST8 = ST8.rename(columns={'variable':'peptide_rank'})

# %%
ST8.columns
# Out:
# Index(['Cell Name', 'Sorted Population', 'TRAV1', 'CDR3α,1', 'TRAV2',
#        'CDR3α,2', 'TRBV1', 'CDR3β,1', 'TRBV2', 'CDR3β,2', 'peptide_rank',
#        'peptide_name'],
#       dtype='object')

# %%
ST8["no_experiment"] = "5"

# %%
ST8 = ST8.astype({"no_experiment": "int64"})

# %%
Exp5 = ST8.merge(ST1, on = ["peptide_name", "no_experiment"])

# %%
Exp5
# Out:
#     Cell Name Sorted Population      TRAV1           CDR3α,1 TRAV2 CDR3α,2  \
# 0        GA10           Neo+WT+     8-3*01    CAVGAEDSNYQLIW   NaN     NaN
# 1         GC5           Neo+WT+  29/DV5*01  CAASATGGTSYGKLTF   NaN     NaN
# 2        GE11           Neo+WT+  29/DV5*01   CAASHGSSNTGKLIF   NaN     NaN
# 3         JA4           Neo+WT+      20*01     CAVLTSGYSTLTF   NaN     NaN
# 4        LE10           Neo+WT+     8-6*01    CAVTDNNAGNMLTF   NaN     NaN
# ..        ...               ...        ...               ...   ...     ...
# 770       JG8           Neo+WT+      10*01      CVVRGGYNKLIF   NaN     NaN
# 771       LC5           Neo+WT+       5*01    CAETLYNQGGKLIF   NaN     NaN
# 772       LH2           Neo+WT+        NaN               NaN   NaN     NaN
# 773       MA3           Neo+WT+        NaN               NaN   NaN     NaN
# 774       NA3           Neo+WT+     8-6*01   CAAFMFSGGYNKLIF   NaN     NaN
#
#              TRBV1          CDR3β,1 TRBV2 CDR3β,2 peptide_rank  \
# 0    6-2*01,6-3*01     CASSYSWGEQFF   NaN     NaN       rank_1
# 1              NaN              NaN   NaN     NaN       rank_1
# 2              NaN              NaN   NaN     NaN       rank_1
# 3            13*01    CASSPMTGAEQFF   NaN     NaN       rank_1
# 4           7-3*01    CASSFGPGYEQYF   NaN     NaN       rank_1
# ..             ...              ...   ...     ...          ...
# 770         5-4*01     CASSSDRGEQFF   NaN     NaN       rank_3
# 771           9*01  CASSGRQGIDTEAFF   NaN     NaN       rank_3
# 772            NaN              NaN   NaN     NaN       rank_3
# 773         7-9*01   CASSLAYRPYEQYF   NaN     NaN       rank_3
# 774          27*01   CASTLGQGNTEAFF   NaN     NaN       rank_3
#
#         peptide_name  no_experiment peptide_seq tetramer_fluorescence HLA_type
# 0     FNDC3B-VVL_L3M              5   VVMSWAPPV                    PE   A02:01
# 1     FNDC3B-VVL_L3M              5   VVMSWAPPV                    PE   A02:01
# 2     FNDC3B-VVL_L3M              5   VVMSWAPPV                    PE   A02:01
# 3     FNDC3B-VVL_L3M              5   VVMSWAPPV                    PE   A02:01
# 4     FNDC3B-VVL_L3M              5   VVMSWAPPV                    PE   A02:01
# ..               ...            ...         ...                   ...      ...
# 770     C17orf75-ALS              5   ALSYTPVEV                   APC   A02:01
# 771       TRIM58-YMV              5   YMVLASPSV                   APC   A02:01
# 772  ZDHHC17-LLL_T4I              5   LLLIFNVSV                    PE   A02:01
# 773  EXOC3L4-ILL_V9I              5   ILLDWAANI                    PE   A02:01
# 774   MRGPRF-RLW_R1W              5   WLWEPLRVV                    PE   A02:01
#
# [775 rows x 16 columns]

# %%
Exp5 = Exp5.rename(columns={"Cell Name": "cell_name", "Sorted Population": "sorted_population", "CDR3α,1": "CDR3alpha_1", "CDR3α,2":"CDR3alpha_2", "CDR3β,1": "CDR3beta_1", "CDR3β,2": "CDR3beta_2"})

# %%
remaining_cols = [col for col in Exp5.columns if col not in ['TRAV1', 'TRAV2', 'TRBV1', 'TRBV2', 'CDR3alpha_1', 'CDR3alpha_2', 'CDR3beta_1', 'CDR3beta_2']]
remaining_cols
# Out:
# ['cell_name',
#  'sorted_population',
#  'peptide_rank',
#  'peptide_name',
#  'no_experiment',
#  'peptide_seq',
#  'tetramer_fluorescence',
#  'HLA_type']

# %%
Exp5.cell_name.duplicated().sum()
# Out:
# 208

# %%
Exp5 = Exp5.drop_duplicates(subset='cell_name')

# %%
Exp5_trav = Exp5.melt(id_vars=remaining_cols, value_vars=['TRAV1', 'TRAV2'], value_name='TRAV')
Exp5_trav
# Out:
#      cell_name sorted_population peptide_rank    peptide_name  no_experiment  \
# 0         GA10           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 1          GC5           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 2         GE11           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 3          JA4           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 4         LE10           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# ...        ...               ...          ...             ...            ...
# 1129       NE3           Neo-WT+       rank_1      GABRG3-TAM              5
# 1130       OE9           Neo-WT+       rank_1       PELP1-LVL              5
# 1131       OH7           Neo-WT+       rank_1  ST6GALNAC2-LLF              5
# 1132       SA3           Neo-WT+       rank_1       ERBB2-ALI              5
# 1133       SC5           Neo-WT+       rank_1         ME1-FLD              5
#
#      peptide_seq tetramer_fluorescence HLA_type variable       TRAV
# 0      VVMSWAPPV                    PE   A02:01    TRAV1     8-3*01
# 1      VVMSWAPPV                    PE   A02:01    TRAV1  29/DV5*01
# 2      VVMSWAPPV                    PE   A02:01    TRAV1  29/DV5*01
# 3      VVMSWAPPV                    PE   A02:01    TRAV1      20*01
# 4      VVMSWAPPV                    PE   A02:01    TRAV1     8-6*01
# ...          ...                   ...      ...      ...        ...
# 1129   TAMDLFVTV                   APC   A02:01    TRAV2        NaN
# 1130   LVLPLVMGV                   APC   A02:01    TRAV2        NaN
# 1131   LLFALYFSA                   APC   A02:01    TRAV2        NaN
# 1132   ALIHHNTHL                   APC   A02:01    TRAV2        NaN
# 1133   FLDEFMEAV                   APC   A02:01    TRAV2        NaN
#
# [1134 rows x 10 columns]

# %%
Exp5_cdr3alpha = Exp5.melt(id_vars=remaining_cols, value_vars=['CDR3alpha_1', 'CDR3alpha_2'], value_name='CDR3alpha')
Exp5_cdr3alpha
# Out:
#      cell_name sorted_population peptide_rank    peptide_name  no_experiment  \
# 0         GA10           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 1          GC5           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 2         GE11           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 3          JA4           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 4         LE10           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# ...        ...               ...          ...             ...            ...
# 1129       NE3           Neo-WT+       rank_1      GABRG3-TAM              5
# 1130       OE9           Neo-WT+       rank_1       PELP1-LVL              5
# 1131       OH7           Neo-WT+       rank_1  ST6GALNAC2-LLF              5
# 1132       SA3           Neo-WT+       rank_1       ERBB2-ALI              5
# 1133       SC5           Neo-WT+       rank_1         ME1-FLD              5
#
#      peptide_seq tetramer_fluorescence HLA_type     variable         CDR3alpha
# 0      VVMSWAPPV                    PE   A02:01  CDR3alpha_1    CAVGAEDSNYQLIW
# 1      VVMSWAPPV                    PE   A02:01  CDR3alpha_1  CAASATGGTSYGKLTF
# 2      VVMSWAPPV                    PE   A02:01  CDR3alpha_1   CAASHGSSNTGKLIF
# 3      VVMSWAPPV                    PE   A02:01  CDR3alpha_1     CAVLTSGYSTLTF
# 4      VVMSWAPPV                    PE   A02:01  CDR3alpha_1    CAVTDNNAGNMLTF
# ...          ...                   ...      ...          ...               ...
# 1129   TAMDLFVTV                   APC   A02:01  CDR3alpha_2               NaN
# 1130   LVLPLVMGV                   APC   A02:01  CDR3alpha_2               NaN
# 1131   LLFALYFSA                   APC   A02:01  CDR3alpha_2               NaN
# 1132   ALIHHNTHL                   APC   A02:01  CDR3alpha_2               NaN
# 1133   FLDEFMEAV                   APC   A02:01  CDR3alpha_2               NaN
#
# [1134 rows x 10 columns]

# %%
Exp5_trbv = Exp5.melt(id_vars=remaining_cols, value_vars=['TRBV1', 'TRBV2'], value_name='TRBV')
Exp5_trbv
# Out:
#      cell_name sorted_population peptide_rank    peptide_name  no_experiment  \
# 0         GA10           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 1          GC5           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 2         GE11           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 3          JA4           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 4         LE10           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# ...        ...               ...          ...             ...            ...
# 1129       NE3           Neo-WT+       rank_1      GABRG3-TAM              5
# 1130       OE9           Neo-WT+       rank_1       PELP1-LVL              5
# 1131       OH7           Neo-WT+       rank_1  ST6GALNAC2-LLF              5
# 1132       SA3           Neo-WT+       rank_1       ERBB2-ALI              5
# 1133       SC5           Neo-WT+       rank_1         ME1-FLD              5
#
#      peptide_seq tetramer_fluorescence HLA_type variable           TRBV
# 0      VVMSWAPPV                    PE   A02:01    TRBV1  6-2*01,6-3*01
# 1      VVMSWAPPV                    PE   A02:01    TRBV1            NaN
# 2      VVMSWAPPV                    PE   A02:01    TRBV1            NaN
# 3      VVMSWAPPV                    PE   A02:01    TRBV1          13*01
# 4      VVMSWAPPV                    PE   A02:01    TRBV1         7-3*01
# ...          ...                   ...      ...      ...            ...
# 1129   TAMDLFVTV                   APC   A02:01    TRBV2            NaN
# 1130   LVLPLVMGV                   APC   A02:01    TRBV2            NaN
# 1131   LLFALYFSA                   APC   A02:01    TRBV2            NaN
# 1132   ALIHHNTHL                   APC   A02:01    TRBV2            NaN
# 1133   FLDEFMEAV                   APC   A02:01    TRBV2            NaN
#
# [1134 rows x 10 columns]

# %%
Exp5_cdr3beta = Exp5.melt(id_vars=remaining_cols, value_vars=['CDR3beta_1', 'CDR3beta_2'], value_name='CDR3beta')
Exp5_cdr3beta
# Out:
#      cell_name sorted_population peptide_rank    peptide_name  no_experiment  \
# 0         GA10           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 1          GC5           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 2         GE11           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 3          JA4           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 4         LE10           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# ...        ...               ...          ...             ...            ...
# 1129       NE3           Neo-WT+       rank_1      GABRG3-TAM              5
# 1130       OE9           Neo-WT+       rank_1       PELP1-LVL              5
# 1131       OH7           Neo-WT+       rank_1  ST6GALNAC2-LLF              5
# 1132       SA3           Neo-WT+       rank_1       ERBB2-ALI              5
# 1133       SC5           Neo-WT+       rank_1         ME1-FLD              5
#
#      peptide_seq tetramer_fluorescence HLA_type    variable       CDR3beta
# 0      VVMSWAPPV                    PE   A02:01  CDR3beta_1   CASSYSWGEQFF
# 1      VVMSWAPPV                    PE   A02:01  CDR3beta_1            NaN
# 2      VVMSWAPPV                    PE   A02:01  CDR3beta_1            NaN
# 3      VVMSWAPPV                    PE   A02:01  CDR3beta_1  CASSPMTGAEQFF
# 4      VVMSWAPPV                    PE   A02:01  CDR3beta_1  CASSFGPGYEQYF
# ...          ...                   ...      ...         ...            ...
# 1129   TAMDLFVTV                   APC   A02:01  CDR3beta_2            NaN
# 1130   LVLPLVMGV                   APC   A02:01  CDR3beta_2            NaN
# 1131   LLFALYFSA                   APC   A02:01  CDR3beta_2            NaN
# 1132   ALIHHNTHL                   APC   A02:01  CDR3beta_2            NaN
# 1133   FLDEFMEAV                   APC   A02:01  CDR3beta_2            NaN
#
# [1134 rows x 10 columns]

# %%
Exp5_trav.drop(columns=['variable'], inplace=True)
Exp5_cdr3alpha.drop(columns=['variable'], inplace=True)
Exp5_trbv.drop(columns=['variable'], inplace=True)
Exp5_cdr3beta.drop(columns=['variable'], inplace=True)

# %%
assert (Exp5_trav.cell_name == Exp5_cdr3alpha.cell_name).all()

# %%
Exp5_final = pd.concat([Exp5_trav,Exp5_cdr3alpha['CDR3alpha'],Exp5_trbv['TRBV'],Exp5_cdr3beta['CDR3beta']], axis=1)
Exp5_final
# Out:
#      cell_name sorted_population peptide_rank    peptide_name  no_experiment  \
# 0         GA10           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 1          GC5           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 2         GE11           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 3          JA4           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 4         LE10           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# ...        ...               ...          ...             ...            ...
# 1129       NE3           Neo-WT+       rank_1      GABRG3-TAM              5
# 1130       OE9           Neo-WT+       rank_1       PELP1-LVL              5
# 1131       OH7           Neo-WT+       rank_1  ST6GALNAC2-LLF              5
# 1132       SA3           Neo-WT+       rank_1       ERBB2-ALI              5
# 1133       SC5           Neo-WT+       rank_1         ME1-FLD              5
#
#      peptide_seq tetramer_fluorescence HLA_type       TRAV         CDR3alpha  \
# 0      VVMSWAPPV                    PE   A02:01     8-3*01    CAVGAEDSNYQLIW
# 1      VVMSWAPPV                    PE   A02:01  29/DV5*01  CAASATGGTSYGKLTF
# 2      VVMSWAPPV                    PE   A02:01  29/DV5*01   CAASHGSSNTGKLIF
# 3      VVMSWAPPV                    PE   A02:01      20*01     CAVLTSGYSTLTF
# 4      VVMSWAPPV                    PE   A02:01     8-6*01    CAVTDNNAGNMLTF
# ...          ...                   ...      ...        ...               ...
# 1129   TAMDLFVTV                   APC   A02:01        NaN               NaN
# 1130   LVLPLVMGV                   APC   A02:01        NaN               NaN
# 1131   LLFALYFSA                   APC   A02:01        NaN               NaN
# 1132   ALIHHNTHL                   APC   A02:01        NaN               NaN
# 1133   FLDEFMEAV                   APC   A02:01        NaN               NaN
#
#                TRBV       CDR3beta
# 0     6-2*01,6-3*01   CASSYSWGEQFF
# 1               NaN            NaN
# 2               NaN            NaN
# 3             13*01  CASSPMTGAEQFF
# 4            7-3*01  CASSFGPGYEQYF
# ...             ...            ...
# 1129            NaN            NaN
# 1130            NaN            NaN
# 1131            NaN            NaN
# 1132            NaN            NaN
# 1133            NaN            NaN
#
# [1134 rows x 12 columns]

# %% [markdown]
# Tutaj sprawdzamy w obrębie remaining_cols czy mamy jakieś duplikaty. Potem sprawdzamy czy gdzieś występuje NaN zestaw TRAV & CDR3alpha.

# %% [markdown]
# Interesują nas oryginały puste, oryginały pełne, oraz duplikaty pełne.

# %%
mask_remaining = Exp5_final.duplicated(subset=remaining_cols)
mask_melted = Exp5_final[['TRAV', 'CDR3alpha', 'TRBV', 'CDR3beta']].isna().all(axis=1)

mask_redundant = mask_remaining & mask_melted

Exp5_final = Exp5_final[~(mask_remaining & mask_melted).values]
Exp5_final
# Out:
#      cell_name sorted_population peptide_rank    peptide_name  no_experiment  \
# 0         GA10           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 1          GC5           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 2         GE11           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 3          JA4           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# 4         LE10           Neo+WT+       rank_1  FNDC3B-VVL_L3M              5
# ...        ...               ...          ...             ...            ...
# 1059      MA12           Neo-WT+       rank_1     SHROOM2-KLL              5
# 1064       LA4           Neo-WT+       rank_1        LCP1-NLF              5
# 1065       LC2           Neo-WT+       rank_1        LCP1-NLF              5
# 1071       KA3           Neo-WT+       rank_1       HAUS3-ILN              5
# 1111       KC5           Neo-WT+       rank_1       DCHS1-TLF              5
#
#      peptide_seq tetramer_fluorescence HLA_type       TRAV         CDR3alpha  \
# 0      VVMSWAPPV                    PE   A02:01     8-3*01    CAVGAEDSNYQLIW
# 1      VVMSWAPPV                    PE   A02:01  29/DV5*01  CAASATGGTSYGKLTF
# 2      VVMSWAPPV                    PE   A02:01  29/DV5*01   CAASHGSSNTGKLIF
# 3      VVMSWAPPV                    PE   A02:01      20*01     CAVLTSGYSTLTF
# 4      VVMSWAPPV                    PE   A02:01     8-6*01    CAVTDNNAGNMLTF
# ...          ...                   ...      ...        ...               ...
# 1059   KLLAGDEIV                   APC   A02:01      25*01        CAGYDYKLSF
# 1064   NLFNRYPAL                   APC   A02:01    26-2*01  CILRGIPRDSSYKLIF
# 1065   NLFNRYPAL                   APC   A02:01      19*01    CALSRGGGADGLTF
# 1071   ILNAMITKI                   APC   A02:01      19*01    CALSEGERDDKIIF
# 1111   TLFTIVGTV                   APC   A02:01    13-1*01       CAAIIGQKLLF
#
#                TRBV       CDR3beta
# 0     6-2*01,6-3*01   CASSYSWGEQFF
# 1               NaN            NaN
# 2               NaN            NaN
# 3             13*01  CASSPMTGAEQFF
# 4            7-3*01  CASSFGPGYEQYF
# ...             ...            ...
# 1059            NaN            NaN
# 1064            NaN            NaN
# 1065            NaN            NaN
# 1071            NaN            NaN
# 1111            NaN            NaN
#
# [608 rows x 12 columns]

# %%
Exp5_final["TRAV"].unique()
# Out:
# array(['8-3*01', '29/DV5*01', '20*01', '8-6*01', nan, '41*01', '17*01',
#        '3*01', '39*01', '22*01', '14/DV4*01', '21*01', '24*01', '12-1*01',
#        '12-2*01', '23/DV6*01', '8-4*01', '27*01', '22*01 F',
#        '38-2/DV8*01', '26-2*01', '19*01', '9-2*01', '10*01', '5*01',
#        '1-2*01', '12-2', '12-3*01', '4*01', '8-1*01', '34*01', '8-1*01 F',
#        '26-1*01', '1-1*01', '8-2*01', '25*01 F', '3*01 F', '2*01', '6*01',
#        '9-2', '35*01', '25*01', '16*01', '29/DV5*01 F', '30*01',
#        '1-2*01\xa0', '38-1*01', '40*01', '21', '13-1*01', '12-1',
#        '36/DV7*01'], dtype=object)

# %%
Exp5_final["TRAV"] = Exp5_final["TRAV"].str.strip()
# Out:
# /tmp/ipykernel_376396/1378927351.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Exp5_final["TRAV"] = Exp5_final["TRAV"].str.strip()

# %%
Exp5_final["TRAV"].unique()
# Out:
# array(['8-3*01', '29/DV5*01', '20*01', '8-6*01', nan, '41*01', '17*01',
#        '3*01', '39*01', '22*01', '14/DV4*01', '21*01', '24*01', '12-1*01',
#        '12-2*01', '23/DV6*01', '8-4*01', '27*01', '22*01 F',
#        '38-2/DV8*01', '26-2*01', '19*01', '9-2*01', '10*01', '5*01',
#        '1-2*01', '12-2', '12-3*01', '4*01', '8-1*01', '34*01', '8-1*01 F',
#        '26-1*01', '1-1*01', '8-2*01', '25*01 F', '3*01 F', '2*01', '6*01',
#        '9-2', '35*01', '25*01', '16*01', '29/DV5*01 F', '30*01',
#        '38-1*01', '40*01', '21', '13-1*01', '12-1', '36/DV7*01'],
#       dtype=object)

# %%
Exp5_final['TRBV'].unique()
# Out:
# array(['6-2*01,6-3*01', nan, '13*01', '7-3*01', '15*01', '3-1*01',
#        '6-5*01', '29-1*01', '5-4*01', '6-4*01', '27*01', '7-9*01',
#        '10-3*01', '5-1*01', '6-1*01', '7-8*01', '11-2*01', '28*01',
#        '5-6*01', '30*01', '19*01', '20-1*01', '2*01', '9*01', '4-1*01',
#        '10-2*01', '25-1*01', '12-3*01,12-4*01', '4-2*01', '6-6*01',
#        '7-6*01', '10-1*01', '11-1*01', '7-2*01', '11-3*01', '14*01',
#        '18*01', '7-4*01', '12-5*01', '4-3*01'], dtype=object)

# %%
Exp5_final = Exp5_final.reset_index(drop=True)

# %%
Exp5_final.to_csv("../../../data/processed/zhang/Exp5_merged.csv.gz")

# %% [markdown]
# <b>ST9 - Experiment 6

# %%
ST9 = pd.read_excel("../../../data/original/zhang/ST9.xlsx")

# %%
new_columns = ["Cell Name", "Sorted Population", "rank_1", "rank_2", "rank_3", "rank_4", "rank_5","TRAV1", "CDR3α,1", "TRAV2", "CDR3α,2", "TRBV1", "CDR3β,1", "TRBV2", "CDR3β,2"]

# %%
ST9.columns = new_columns

# %%
ST9 = ST9.iloc[2:, :].reset_index(drop=True)

# %%
ST9
# Out:
#     Cell Name Sorted Population      rank_1 rank_2 rank_3 rank_4 rank_5  \
# 0         AD5           Neo+WT+           0      0      0      0      0
# 1         AD9           Neo+WT+           0      0      0      0      0
# 2         BC5           Neo+WT+           0      0      0      0      0
# 3         BC8           Neo+WT+           0      0      0      0      0
# 4         BD8           Neo+WT+           0      0      0      0      0
# ..        ...               ...         ...    ...    ...    ...    ...
# 269       BF4           Neo-WT+   TRPV4-FMI      0      0      0      0
# 270       AB9           Neo-WT+  TTLL12-KLP      0      0      0      0
# 271       AC3           Neo-WT+   WDR46-FLT      0      0      0      0
# 272       AG2           Neo-WT+  ZDHHC7-SLL      0      0      0      0
# 273       FE7           Neo-WT+  ZDHHC7-SLL      0      0      0      0
#
#          TRAV1           CDR3α,1 TRAV2         CDR3α,2            TRBV1  \
# 0        17*01   CATDAAGSTLGRLYF  3*01  CAVRDSDYGQNFVF  12-3*01,12-4*01
# 1       1-2*01   CAVRVLSYNFNKFYF   NaN             NaN          20-1*01
# 2        24*01    CALNSGGGADGLTF   NaN             NaN           5-1*01
# 3        16*01    CAPPLNQAGTALIF   NaN             NaN  12-3*01,12-4*01
# 4          NaN               NaN   NaN             NaN           4-3*01
# ..         ...               ...   ...             ...              ...
# 269        NaN               NaN   NaN             NaN             9*01
# 270       5*01  CAESSSMDTGRRALTF   NaN             NaN           5-5*01
# 271        NaN               NaN   NaN             NaN             9*01
# 272  14/DV4*01  CAMREFPQGGSEKLVF   NaN             NaN           4-2*01
# 273      19*01     CALTNTGRRALTF   NaN             NaN            27*01
#
#                   CDR3β,1 TRBV2 CDR3β,2
# 0    CASSPPHNDRDILNTDTQYF   NaN     NaN
# 1           CSARTDGSYEQYF   NaN     NaN
# 2            CASSWGGYEQYF   NaN     NaN
# 3          CASSPGAGSTEAFF   NaN     NaN
# 4       CASSQDPRTGANYGYTF   NaN     NaN
# ..                    ...   ...     ...
# 269      CASSDRQGIATGELFF   NaN     NaN
# 270       CASSLNPGTSYEQYF   NaN     NaN
# 271        CASNSGGAYNEQFF   NaN     NaN
# 272       CASSQGQGLQETQYF   NaN     NaN
# 273       CASSLYGELYYGYTF   NaN     NaN
#
# [274 rows x 15 columns]

# %%
remaining_cols = [col for col in ST9.columns if col not in ["rank_1", "rank_2", "rank_3", "rank_4", "rank_5"]]
remaining_cols
# Out:
# ['Cell Name',
#  'Sorted Population',
#  'TRAV1',
#  'CDR3α,1',
#  'TRAV2',
#  'CDR3α,2',
#  'TRBV1',
#  'CDR3β,1',
#  'TRBV2',
#  'CDR3β,2']

# %%
ST9 = ST9.melt(id_vars=remaining_cols, value_vars=["rank_1", "rank_2", "rank_3", "rank_4", "rank_5"], value_name='peptide_name')

# %%
ST9 = ST9.rename(columns={'variable':'peptide_rank'})

# %%
ST9.columns
# Out:
# Index(['Cell Name', 'Sorted Population', 'TRAV1', 'CDR3α,1', 'TRAV2',
#        'CDR3α,2', 'TRBV1', 'CDR3β,1', 'TRBV2', 'CDR3β,2', 'peptide_rank',
#        'peptide_name'],
#       dtype='object')

# %%
ST9["no_experiment"] = "6"

# %%
ST9 = ST9.astype({"no_experiment": "int64"})

# %%
Exp6 = ST9.merge(ST1, on = ["peptide_name", "no_experiment"])

# %%
Exp6
# Out:
#     Cell Name Sorted Population        TRAV1           CDR3α,1    TRAV2  \
# 0         BA7           Neo+WT+       8-3*01       CAVAPSNDMRF      NaN
# 1         BE6           Neo-WT+  38-2/DV8*01         CAYTDKLIF      NaN
# 2         FF1           Neo+WT+         5*01     CAEIYNQGGKLIF      NaN
# 3        FH12           Neo+WT+          NaN               NaN      NaN
# 4         AD7           Neo+WT-        24*01     CALIYNQGGKLIF      NaN
# ..        ...               ...          ...               ...      ...
# 364       BA7           Neo+WT+       8-3*01       CAVAPSNDMRF      NaN
# 365       AE3           Neo+WT+          NaN               NaN      NaN
# 366       FB6           Neo+WT+         5*01      CAECGGNNDMRF  12-2*01
# 367       BE5           Neo-WT+        24*01       CAFSRYSTLTF      NaN
# 368      AD12           Neo+WT+        19*01  CALSEAEGGATNKLIF      NaN
#
#              CDR3α,2            TRBV1          CDR3β,1 TRBV2 CDR3β,2  \
# 0                NaN              NaN              NaN   NaN     NaN
# 1                NaN           6-6*01     CASGDLSYEQYF   NaN     NaN
# 2                NaN            19*01  CASSTPGGWNTEAFF   NaN     NaN
# 3                NaN              NaN              NaN   NaN     NaN
# 4                NaN             2*01    CASNSGPNEKLFF   NaN     NaN
# ..               ...              ...              ...   ...     ...
# 364              NaN              NaN              NaN   NaN     NaN
# 365              NaN           5-6*01   CASSPVLGTYGYTF   NaN     NaN
# 366  CAVPYSGAGSYQLTF            28*01      CASSLNTEAFF   NaN     NaN
# 367              NaN            19*01     CASSIGDYEQYF   NaN     NaN
# 368              NaN  12-3*01,12-4*01    CASSFGGLYGYTF   NaN     NaN
#
#     peptide_rank   peptide_name  no_experiment peptide_seq  \
# 0         rank_1     AKAP13-KLM              6   KLMNIQQQL
# 1         rank_1     AKAP13-KLM              6   KLMNIQQQL
# 2         rank_1  APBB2-VQY_L7F              6   VQYLGMFPV
# 3         rank_1  APBB2-VQY_L7F              6   VQYLGMFPV
# 4         rank_1  APBB2-VQY_L7F              6   VQYLGMFPV
# ..           ...            ...            ...         ...
# 364       rank_3    SMOX-KLA_KN              6   KLANPLPYT
# 365       rank_3   MLL2-ALS_L8H              6   ALSPVIPHI
# 366       rank_3     SREBF1-YLQ              6   YLQDSLATT
# 367       rank_3       MYPN-RVI              6   RVIGMPPPV
# 368       rank_4   SSPN-LMA_S8F              6   LMASISSFL
#
#     tetramer_fluorescence HLA_type
# 0                     APC   A02:01
# 1                     APC   A02:01
# 2                      PE   A02:01
# 3                      PE   A02:01
# 4                      PE   A02:01
# ..                    ...      ...
# 364                    PE   A02:01
# 365                    PE   A02:01
# 366                   APC   A02:01
# 367                   APC   A02:01
# 368                    PE   A02:01
#
# [369 rows x 16 columns]

# %%
Exp6 = Exp6.rename(columns={"Cell Name": "cell_name", "Sorted Population": "sorted_population", "CDR3α,1": "CDR3alpha_1", "CDR3α,2":"CDR3alpha_2", "CDR3β,1": "CDR3beta_1", "CDR3β,2": "CDR3beta_2"})

# %%
remaining_cols = [col for col in Exp6.columns if col not in ['TRAV1', 'TRAV2', 'TRBV1', 'TRBV2', 'CDR3alpha_1', 'CDR3alpha_2', 'CDR3beta_1', 'CDR3beta_2']]
remaining_cols
# Out:
# ['cell_name',
#  'sorted_population',
#  'peptide_rank',
#  'peptide_name',
#  'no_experiment',
#  'peptide_seq',
#  'tetramer_fluorescence',
#  'HLA_type']

# %%
Exp6.cell_name.duplicated().sum()
# Out:
# 114

# %%
Exp6_trav = Exp6.melt(id_vars=remaining_cols, value_vars=['TRAV1', 'TRAV2'], value_name='TRAV')
Exp6_trav
# Out:
#     cell_name sorted_population peptide_rank   peptide_name  no_experiment  \
# 0         BA7           Neo+WT+       rank_1     AKAP13-KLM              6
# 1         BE6           Neo-WT+       rank_1     AKAP13-KLM              6
# 2         FF1           Neo+WT+       rank_1  APBB2-VQY_L7F              6
# 3        FH12           Neo+WT+       rank_1  APBB2-VQY_L7F              6
# 4         AD7           Neo+WT-       rank_1  APBB2-VQY_L7F              6
# ..        ...               ...          ...            ...            ...
# 733       BA7           Neo+WT+       rank_3    SMOX-KLA_KN              6
# 734       AE3           Neo+WT+       rank_3   MLL2-ALS_L8H              6
# 735       FB6           Neo+WT+       rank_3     SREBF1-YLQ              6
# 736       BE5           Neo-WT+       rank_3       MYPN-RVI              6
# 737      AD12           Neo+WT+       rank_4   SSPN-LMA_S8F              6
#
#     peptide_seq tetramer_fluorescence HLA_type variable         TRAV
# 0     KLMNIQQQL                   APC   A02:01    TRAV1       8-3*01
# 1     KLMNIQQQL                   APC   A02:01    TRAV1  38-2/DV8*01
# 2     VQYLGMFPV                    PE   A02:01    TRAV1         5*01
# 3     VQYLGMFPV                    PE   A02:01    TRAV1          NaN
# 4     VQYLGMFPV                    PE   A02:01    TRAV1        24*01
# ..          ...                   ...      ...      ...          ...
# 733   KLANPLPYT                    PE   A02:01    TRAV2          NaN
# 734   ALSPVIPHI                    PE   A02:01    TRAV2          NaN
# 735   YLQDSLATT                   APC   A02:01    TRAV2      12-2*01
# 736   RVIGMPPPV                   APC   A02:01    TRAV2          NaN
# 737   LMASISSFL                    PE   A02:01    TRAV2          NaN
#
# [738 rows x 10 columns]

# %%
Exp6_cdr3alpha = Exp6.melt(id_vars=remaining_cols, value_vars=['CDR3alpha_1', 'CDR3alpha_2'], value_name='CDR3alpha')
Exp6_cdr3alpha
# Out:
#     cell_name sorted_population peptide_rank   peptide_name  no_experiment  \
# 0         BA7           Neo+WT+       rank_1     AKAP13-KLM              6
# 1         BE6           Neo-WT+       rank_1     AKAP13-KLM              6
# 2         FF1           Neo+WT+       rank_1  APBB2-VQY_L7F              6
# 3        FH12           Neo+WT+       rank_1  APBB2-VQY_L7F              6
# 4         AD7           Neo+WT-       rank_1  APBB2-VQY_L7F              6
# ..        ...               ...          ...            ...            ...
# 733       BA7           Neo+WT+       rank_3    SMOX-KLA_KN              6
# 734       AE3           Neo+WT+       rank_3   MLL2-ALS_L8H              6
# 735       FB6           Neo+WT+       rank_3     SREBF1-YLQ              6
# 736       BE5           Neo-WT+       rank_3       MYPN-RVI              6
# 737      AD12           Neo+WT+       rank_4   SSPN-LMA_S8F              6
#
#     peptide_seq tetramer_fluorescence HLA_type     variable        CDR3alpha
# 0     KLMNIQQQL                   APC   A02:01  CDR3alpha_1      CAVAPSNDMRF
# 1     KLMNIQQQL                   APC   A02:01  CDR3alpha_1        CAYTDKLIF
# 2     VQYLGMFPV                    PE   A02:01  CDR3alpha_1    CAEIYNQGGKLIF
# 3     VQYLGMFPV                    PE   A02:01  CDR3alpha_1              NaN
# 4     VQYLGMFPV                    PE   A02:01  CDR3alpha_1    CALIYNQGGKLIF
# ..          ...                   ...      ...          ...              ...
# 733   KLANPLPYT                    PE   A02:01  CDR3alpha_2              NaN
# 734   ALSPVIPHI                    PE   A02:01  CDR3alpha_2              NaN
# 735   YLQDSLATT                   APC   A02:01  CDR3alpha_2  CAVPYSGAGSYQLTF
# 736   RVIGMPPPV                   APC   A02:01  CDR3alpha_2              NaN
# 737   LMASISSFL                    PE   A02:01  CDR3alpha_2              NaN
#
# [738 rows x 10 columns]

# %%
Exp6_trbv = Exp6.melt(id_vars=remaining_cols, value_vars=['TRBV1', 'TRBV2'], value_name='TRBV')
Exp6_trbv
# Out:
#     cell_name sorted_population peptide_rank   peptide_name  no_experiment  \
# 0         BA7           Neo+WT+       rank_1     AKAP13-KLM              6
# 1         BE6           Neo-WT+       rank_1     AKAP13-KLM              6
# 2         FF1           Neo+WT+       rank_1  APBB2-VQY_L7F              6
# 3        FH12           Neo+WT+       rank_1  APBB2-VQY_L7F              6
# 4         AD7           Neo+WT-       rank_1  APBB2-VQY_L7F              6
# ..        ...               ...          ...            ...            ...
# 733       BA7           Neo+WT+       rank_3    SMOX-KLA_KN              6
# 734       AE3           Neo+WT+       rank_3   MLL2-ALS_L8H              6
# 735       FB6           Neo+WT+       rank_3     SREBF1-YLQ              6
# 736       BE5           Neo-WT+       rank_3       MYPN-RVI              6
# 737      AD12           Neo+WT+       rank_4   SSPN-LMA_S8F              6
#
#     peptide_seq tetramer_fluorescence HLA_type variable    TRBV
# 0     KLMNIQQQL                   APC   A02:01    TRBV1     NaN
# 1     KLMNIQQQL                   APC   A02:01    TRBV1  6-6*01
# 2     VQYLGMFPV                    PE   A02:01    TRBV1   19*01
# 3     VQYLGMFPV                    PE   A02:01    TRBV1     NaN
# 4     VQYLGMFPV                    PE   A02:01    TRBV1    2*01
# ..          ...                   ...      ...      ...     ...
# 733   KLANPLPYT                    PE   A02:01    TRBV2     NaN
# 734   ALSPVIPHI                    PE   A02:01    TRBV2     NaN
# 735   YLQDSLATT                   APC   A02:01    TRBV2     NaN
# 736   RVIGMPPPV                   APC   A02:01    TRBV2     NaN
# 737   LMASISSFL                    PE   A02:01    TRBV2     NaN
#
# [738 rows x 10 columns]

# %%
Exp6_cdr3beta = Exp6.melt(id_vars=remaining_cols, value_vars=['CDR3beta_1', 'CDR3beta_2'], value_name='CDR3beta')
Exp6_cdr3beta
# Out:
#     cell_name sorted_population peptide_rank   peptide_name  no_experiment  \
# 0         BA7           Neo+WT+       rank_1     AKAP13-KLM              6
# 1         BE6           Neo-WT+       rank_1     AKAP13-KLM              6
# 2         FF1           Neo+WT+       rank_1  APBB2-VQY_L7F              6
# 3        FH12           Neo+WT+       rank_1  APBB2-VQY_L7F              6
# 4         AD7           Neo+WT-       rank_1  APBB2-VQY_L7F              6
# ..        ...               ...          ...            ...            ...
# 733       BA7           Neo+WT+       rank_3    SMOX-KLA_KN              6
# 734       AE3           Neo+WT+       rank_3   MLL2-ALS_L8H              6
# 735       FB6           Neo+WT+       rank_3     SREBF1-YLQ              6
# 736       BE5           Neo-WT+       rank_3       MYPN-RVI              6
# 737      AD12           Neo+WT+       rank_4   SSPN-LMA_S8F              6
#
#     peptide_seq tetramer_fluorescence HLA_type    variable         CDR3beta
# 0     KLMNIQQQL                   APC   A02:01  CDR3beta_1              NaN
# 1     KLMNIQQQL                   APC   A02:01  CDR3beta_1     CASGDLSYEQYF
# 2     VQYLGMFPV                    PE   A02:01  CDR3beta_1  CASSTPGGWNTEAFF
# 3     VQYLGMFPV                    PE   A02:01  CDR3beta_1              NaN
# 4     VQYLGMFPV                    PE   A02:01  CDR3beta_1    CASNSGPNEKLFF
# ..          ...                   ...      ...         ...              ...
# 733   KLANPLPYT                    PE   A02:01  CDR3beta_2              NaN
# 734   ALSPVIPHI                    PE   A02:01  CDR3beta_2              NaN
# 735   YLQDSLATT                   APC   A02:01  CDR3beta_2              NaN
# 736   RVIGMPPPV                   APC   A02:01  CDR3beta_2              NaN
# 737   LMASISSFL                    PE   A02:01  CDR3beta_2              NaN
#
# [738 rows x 10 columns]

# %%
Exp6_trav.drop(columns=['variable'], inplace=True)
Exp6_cdr3alpha.drop(columns=['variable'], inplace=True)
Exp6_trbv.drop(columns=['variable'], inplace=True)
Exp6_cdr3beta.drop(columns=['variable'], inplace=True)

# %%
assert (Exp6_trav.cell_name == Exp6_cdr3alpha.cell_name).all()

# %%
Exp6_final = pd.concat([Exp6_trav,Exp6_cdr3alpha['CDR3alpha'],Exp6_trbv['TRBV'],Exp6_cdr3beta['CDR3beta']], axis=1)
Exp6_final
# Out:
#     cell_name sorted_population peptide_rank   peptide_name  no_experiment  \
# 0         BA7           Neo+WT+       rank_1     AKAP13-KLM              6
# 1         BE6           Neo-WT+       rank_1     AKAP13-KLM              6
# 2         FF1           Neo+WT+       rank_1  APBB2-VQY_L7F              6
# 3        FH12           Neo+WT+       rank_1  APBB2-VQY_L7F              6
# 4         AD7           Neo+WT-       rank_1  APBB2-VQY_L7F              6
# ..        ...               ...          ...            ...            ...
# 733       BA7           Neo+WT+       rank_3    SMOX-KLA_KN              6
# 734       AE3           Neo+WT+       rank_3   MLL2-ALS_L8H              6
# 735       FB6           Neo+WT+       rank_3     SREBF1-YLQ              6
# 736       BE5           Neo-WT+       rank_3       MYPN-RVI              6
# 737      AD12           Neo+WT+       rank_4   SSPN-LMA_S8F              6
#
#     peptide_seq tetramer_fluorescence HLA_type         TRAV        CDR3alpha  \
# 0     KLMNIQQQL                   APC   A02:01       8-3*01      CAVAPSNDMRF
# 1     KLMNIQQQL                   APC   A02:01  38-2/DV8*01        CAYTDKLIF
# 2     VQYLGMFPV                    PE   A02:01         5*01    CAEIYNQGGKLIF
# 3     VQYLGMFPV                    PE   A02:01          NaN              NaN
# 4     VQYLGMFPV                    PE   A02:01        24*01    CALIYNQGGKLIF
# ..          ...                   ...      ...          ...              ...
# 733   KLANPLPYT                    PE   A02:01          NaN              NaN
# 734   ALSPVIPHI                    PE   A02:01          NaN              NaN
# 735   YLQDSLATT                   APC   A02:01      12-2*01  CAVPYSGAGSYQLTF
# 736   RVIGMPPPV                   APC   A02:01          NaN              NaN
# 737   LMASISSFL                    PE   A02:01          NaN              NaN
#
#        TRBV         CDR3beta
# 0       NaN              NaN
# 1    6-6*01     CASGDLSYEQYF
# 2     19*01  CASSTPGGWNTEAFF
# 3       NaN              NaN
# 4      2*01    CASNSGPNEKLFF
# ..      ...              ...
# 733     NaN              NaN
# 734     NaN              NaN
# 735     NaN              NaN
# 736     NaN              NaN
# 737     NaN              NaN
#
# [738 rows x 12 columns]

# %% [markdown]
# Tutaj sprawdzamy w obrębie remaining_cols czy mamy jakieś duplikaty. Potem sprawdzamy czy gdzieś występuje NaN zestaw TRAV & CDR3alpha.

# %% [markdown]
# Interesują nas oryginały puste, oryginały pełne, oraz duplikaty pełne.

# %%
mask_remaining = Exp6_final.duplicated(subset=remaining_cols)
mask_melted = Exp6_final[['TRAV', 'CDR3alpha', 'TRBV', 'CDR3beta']].isna().all(axis=1)

mask_redundant = mask_remaining & mask_melted

Exp6_final = Exp6_final[~(mask_remaining & mask_melted).values]
Exp6_final
# Out:
#     cell_name sorted_population peptide_rank   peptide_name  no_experiment  \
# 0         BA7           Neo+WT+       rank_1     AKAP13-KLM              6
# 1         BE6           Neo-WT+       rank_1     AKAP13-KLM              6
# 2         FF1           Neo+WT+       rank_1  APBB2-VQY_L7F              6
# 3        FH12           Neo+WT+       rank_1  APBB2-VQY_L7F              6
# 4         AD7           Neo+WT-       rank_1  APBB2-VQY_L7F              6
# ..        ...               ...          ...            ...            ...
# 696       AC6           Neo+WT+       rank_2  DHX33-LLA_M4I              6
# 701      AD11           Neo+WT+       rank_2     FNDC3B-VVL              6
# 724       FB6           Neo+WT+       rank_2         SSPN-9              6
# 726       BF8           Neo+WT+       rank_2      VN1R5-MII              6
# 735       FB6           Neo+WT+       rank_3     SREBF1-YLQ              6
#
#     peptide_seq tetramer_fluorescence HLA_type         TRAV         CDR3alpha  \
# 0     KLMNIQQQL                   APC   A02:01       8-3*01       CAVAPSNDMRF
# 1     KLMNIQQQL                   APC   A02:01  38-2/DV8*01         CAYTDKLIF
# 2     VQYLGMFPV                    PE   A02:01         5*01     CAEIYNQGGKLIF
# 3     VQYLGMFPV                    PE   A02:01          NaN               NaN
# 4     VQYLGMFPV                    PE   A02:01        24*01     CALIYNQGGKLIF
# ..          ...                   ...      ...          ...               ...
# 696   LLAIKVPNV                    PE   A02:01      26-2*01     CILREGSNYQLIW
# 701   VVLSWAPPV                   APC   A02:01        24*01      CAPNNAGNMLTF
# 724   FLMASISSS                   APC   A02:01      12-2*01   CAVPYSGAGSYQLTF
# 726   MIISHLSLI                   APC   A02:01  38-2/DV8*01  CACNNAGGTSYGKLTF
# 735   YLQDSLATT                   APC   A02:01      12-2*01   CAVPYSGAGSYQLTF
#
#        TRBV         CDR3beta
# 0       NaN              NaN
# 1    6-6*01     CASGDLSYEQYF
# 2     19*01  CASSTPGGWNTEAFF
# 3       NaN              NaN
# 4      2*01    CASNSGPNEKLFF
# ..      ...              ...
# 696     NaN              NaN
# 701     NaN              NaN
# 724     NaN              NaN
# 726     NaN              NaN
# 735     NaN              NaN
#
# [405 rows x 12 columns]

# %%
Exp6_final["TRAV"].unique()
# Out:
# array(['8-3*01', '38-2/DV8*01', '5*01', nan, '24*01', '12-2*01', '17*01',
#        '3*01', '41*01', '14/DV4*01', '4*01', '26-2*01', '12-3*01',
#        '20*01', '27*01', '12-1*01', '21*01', '23/DV6*01', '16*01',
#        '30*01', '8-1*01', '1-2*01 F', '39*01', '38-1*01', '9-2*01',
#        '19*01', '41*01 F', '1-2*01', '8-6*01', '26-1*01', '22*01',
#        '8-2*01', '25*01', '10*01', '29/DV5*01', '36/DV7', '35*01',
#        '14/DV4*01 F', '40*01', '35', '6*01'], dtype=object)

# %%
Exp6_final["TRBV"].unique()
# Out:
# array([nan, '6-6*01', '19*01', '2*01', '30*01', '27*01', '29-1*01',
#        '5-6*01', '4-3*01', '6-2*01,6-3*01', '6-5*01', '5-1*01', '13*01',
#        '20-1*01', '3-1*01', '14*01', '9*01', '10-2*01', '7-9*01',
#        '7-8*01', '12-3*01,12-4*01', '4-1*01', '7-2*01', '4-2*01',
#        '7-3*01', '25-1*01', '5-4*01', '5-8*01', '15*01', '6-1*01',
#        '28*01', '11-2*01', '6-4*01', '7-6*01', '10-3*01', '11-3*01',
#        '5-5*01'], dtype=object)

# %%
Exp6_final = Exp6_final.reset_index(drop=True)

# %%
Exp6_final.to_csv("../../../data/processed/zhang/Exp6_merged.csv.gz")
