# %%
import pandas as pd
import os

# %%
attaf = pd.read_csv("../../../data/original/attaf_original.csv.gz")

# %%
attaf
# Out:
#   Sample ID  Read Count  Frequency    CDR3 nucleotide   V GENE  J GENE  \
# 0   09-0193        6945      3.344  GTGCTGTCGGGAATAAT   TRAV20  TRAJ39
# 1   09-0207        6972      1.520  GTGCTGTGGGCAATAAT   TRAV20  TRAJ39
# 2   09-0207        3654      0.796  GTGCTGTGGGGAATAAT   TRAV20  TRAJ39
# 3   09-0207           8      0.002  GTGCTGTTGGTAATAAT   TRAV20  TRAJ39
# 4   09-0207           7      0.002  GTGCTGTGGGTAATAAT  TRAV8-3  TRAJ39
# 5   09-0195          68      0.020  GTGCTGTTGGGAATAAT   TRAV20  TRAJ39
# 6   09-0195           9      0.003  GTGCTGTCGGTAATAAT   TRAV20  TRAJ39
# 7   09-0195        3800      1.082  GTGCTGTGGGGGCTAAT   TRAV20  TRAJ39
#
#          CDR3 aa
# 0  CAVGNNAGNMLTF
# 1  CAVGNNAGNMLTF
# 2  CAVGNNAGNMLTF
# 3  CAVGNNAGNMLTF
# 4  CAVGNNAGNMLTF
# 5  CAVGNNAGNMLTF
# 6  CAVGNNAGNMLTF
# 7  CAVGANAGNMLTF

# %%
attaf = attaf[["V GENE", "J GENE", "CDR3 aa"]]

# %%
attaf.columns = ["TRAV", "TRAJ", "CDR3a"]

# %%
attaf["TRAV"] = attaf["TRAV"].str.replace("TRAV", "")
attaf["TRAJ"] = attaf["TRAJ"].str.replace("TRAJ", "")
# Out:
# /tmp/ipykernel_372809/2178871583.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attaf["TRAV"] = attaf["TRAV"].str.replace("TRAV", "")
# /tmp/ipykernel_372809/2178871583.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attaf["TRAJ"] = attaf["TRAJ"].str.replace("TRAJ", "")

# %%
attaf["HLA_type"] = "HLA-B*44:03"
attaf["peptide_seq"] = "NEGVKAAW"
attaf["peptide_source"] = "CMV"
attaf["tcr_source_organism"] = "human"
attaf["experiment_type"] = "tetramer-sort, TCR seq"
attaf["dataset"] = "Attaf"
attaf["tissue"] = "whole blood"
# Out:
# /tmp/ipykernel_372809/3176428077.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attaf["HLA_type"] = "HLA-B*44:03"
# /tmp/ipykernel_372809/3176428077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attaf["peptide_seq"] = "NEGVKAAW"
# /tmp/ipykernel_372809/3176428077.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
attaf = attaf [["peptide_seq", "HLA_type", "CDR3a", "TRAJ", "TRAV", "peptide_source", "tcr_source_organism", "tissue", "experiment_type", "dataset"]]

# %%
attaf
# Out:
#   peptide_seq     HLA_type          CDR3a TRAJ TRAV peptide_source  \
# 0    NEGVKAAW  HLA-B*44:03  CAVGNNAGNMLTF   39   20            CMV
# 1    NEGVKAAW  HLA-B*44:03  CAVGNNAGNMLTF   39   20            CMV
# 2    NEGVKAAW  HLA-B*44:03  CAVGNNAGNMLTF   39   20            CMV
# 3    NEGVKAAW  HLA-B*44:03  CAVGNNAGNMLTF   39   20            CMV
# 4    NEGVKAAW  HLA-B*44:03  CAVGNNAGNMLTF   39  8-3            CMV
# 5    NEGVKAAW  HLA-B*44:03  CAVGNNAGNMLTF   39   20            CMV
# 6    NEGVKAAW  HLA-B*44:03  CAVGNNAGNMLTF   39   20            CMV
# 7    NEGVKAAW  HLA-B*44:03  CAVGANAGNMLTF   39   20            CMV
#
#   tcr_source_organism       tissue         experiment_type dataset
# 0               human  whole blood  tetramer-sort, TCR seq   Attaf
# 1               human  whole blood  tetramer-sort, TCR seq   Attaf
# 2               human  whole blood  tetramer-sort, TCR seq   Attaf
# 3               human  whole blood  tetramer-sort, TCR seq   Attaf
# ...

# %%
attaf = attaf.drop_duplicates()

# %%
attaf = attaf.reset_index(drop=True)

# %%
attaf.to_csv("../../../data/processed/attaf_input.csv.gz", index=False)
